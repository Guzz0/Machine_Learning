# %%
# Nos descargamos el dataset de OpenDataSoft
# !wget -O "airbnb-listings.csv" "https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/airbnb-listings/exports/csv?lang=en&facet=facet(name%3D%22host_verifications%22%2C%20disjunctive%3Dtrue)&facet=facet(name%3D%22amenities%22%2C%20disjunctive%3Dtrue)&facet=facet(name%3D%22features%22%2C%20disjunctive%3Dtrue)&qv1=(Madrid)&timezone=Europe%2FBerlin&use_labels=true&delimiter=%3B&export_format=csv"
# Out:
# --2023-03-19 08:37:23--  https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/airbnb-listings/exports/csv?lang=en&facet=facet(name%3D%22host_verifications%22%2C%20disjunctive%3Dtrue)&facet=facet(name%3D%22amenities%22%2C%20disjunctive%3Dtrue)&facet=facet(name%3D%22features%22%2C%20disjunctive%3Dtrue)&qv1=(Madrid)&timezone=Europe%2FBerlin&use_labels=true&delimiter=%3B&export_format=csv
# Resolving public.opendatasoft.com (public.opendatasoft.com)... 34.249.199.226, 34.248.20.69
# Connecting to public.opendatasoft.com (public.opendatasoft.com)|34.249.199.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘airbnb-listings.csv’
#
# airbnb-listings.csv     [            <=>     ]  57.85M  1023KB/s    in 65s
#
# 2023-03-19 08:38:31 (917 KB/s) - ‘airbnb-listings.csv’ saved [60658093]

# %%
# Leemos el dataset con pandas y mostramos los 5 primeros registros
import pandas as pd
data = pd.read_csv('airbnb-listings.csv', sep = ';')

data.shape
# Out:
# (14780, 89)

# %%
import numpy as np

# %% [markdown]
# #LIMPIEZA Y PREPARACION DE DATOS
# Vamos a limpiar los datos...
#
# Queremos solo las propiedades de España para ser mas exactos la ciudad sera Madrid donde tenemos mas datos..
#
# en la columna codigo postal vamos a quedarnos con los codigos postales escritos correctamente y que pertenezcan a madrid
#
# vamos a limpiar columnas que no nos interesan, que no tienen suficientes datos y tambien limpiar las filas de precios que sean mayor a 200

# %% [markdown]
# ## Tenemos esta lista de columnas que por logica solo viendo su nombre no aporta ninguna utlidad para realizar la predccion deseada(col relacionadas con el host,. Por ello realizamos un drop de estas.
#
# *'Name','Host Response Rate','Host Response Time',
# 'ID', 'Listing Url', 'Scrape ID', 'Last Scraped',  'Medium Url',
# 'Picture Url', 'XL Picture Url', 'Host ID', 'Host URL', 'Host Name',
# 'Host Thumbnail Url', 'Host Picture Url', 'Host Neighbourhood', 'Weekly Price', 'Monthly Price', 'Calendar Updated', 'Calendar last Scraped', 'First Review', 'Last Review', 'Reviews per Month', 'Geolocation', 'Calculated host listings count','Host Listings Count', 'Host Total Listings Count','Host Since','Interaction', 'House Rules','Review Scores Communication', 'Review Scores Location',  'Review Scores Value','Review Scores Cleanliness',  'Review Scores Checkin','Number of Reviews','Review Scores Rating',  'Review Scores Accuracy','City', 'Country Code','Minimum Nights','Notes', 'Transit','Thumbnail Url','Host Location', 'Host About','Host Verifications','Host Acceptance Rate'*

# %%
#1

data = data.loc[(data['Country Code'] == 'ES') & (data['City'] == 'Madrid')]

# lista descargada online de codigos postales de madrid para asi eliminar los datos incorrectos o que este fuera de madrid
# Códigos postales válidos
valid_zipcodes = ['28000', '28001', '28002', '28003', '28004', '28005', '28006', '28007',
                  '28008', '28009', '28010', '28011', '28012', '28013', '28014', '28015', 
                  '28016', '28017', '28018', '28019', '28020', '28021', '28022', '28023', 
                  '28024', '28025', '28026', '28027', '28028', '28029', '28030', '28031', 
                  '28032', '28033', '28034', '28035', '28036', '28037', '28038', '28039', 
                  '28040', '28041', '28042', '28043', '28044', '28045', '28046', '28047', 
                  '28048', '28049', '28050', '28051', '28052', '28053', '28054', '28055']

# Códigos postales a corregir
zipcodes_to_fix = {
    '2804': '28004',
    '2015': '28015',
    '280013': '28013'
}

# Corrección de códigos postales
data['Zipcode'] = data['Zipcode'].astype(str) # Convertir la columna a tipo string
data['Zipcode'] = data['Zipcode'].str.replace('\n', '') # Remover saltos de línea
data['Zipcode'] = data['Zipcode'].str.replace('Madrid ', '') # Remover prefijo "Madrid "
data['Zipcode'] = data['Zipcode'].replace(zipcodes_to_fix) # Corregir códigos postales

# Filtrar por códigos postales válidos
data = data[data['Zipcode'].isin(valid_zipcodes)]

# Print the number of unique postal codes
print(len(data.loc[data['Country Code'] == 'ES', 'Zipcode'].unique()))


data['Zipcode'] = data['Zipcode'].astype(int)


print(np.unique(data.Zipcode))
# Out:
# 55
# [28001 28002 28003 28004 28005 28006 28007 28008 28009 28010 28011 28012
#  28013 28014 28015 28016 28017 28018 28019 28020 28021 28022 28023 28024
#  28025 28026 28027 28028 28029 28030 28031 28032 28033 28034 28035 28036
#  28037 28038 28039 28040 28041 28042 28043 28044 28045 28046 28047 28048
#  28049 28050 28051 28052 28053 28054 28055]

# %%
# 3.vamos a ver de cuantos registros disponemos y de cuantas variables
print(data.shape)
# Out:
# (12751, 89)

# %%
# Hacemos un drop de todas las columnas que por Logica no son utiles.
not_useful_columns = ['Name','Host Response Rate','Host Response Time', 'ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Medium Url', 
 'Picture Url', 'XL Picture Url', 'Host ID', 'Host URL', 'Host Name', 'Host Thumbnail Url', 'Host Picture Url','Host Neighbourhood', 'Weekly Price',
  'Monthly Price', 'Calendar Updated', 'Calendar last Scraped', 'First Review', 'Last Review', 'Reviews per Month', 'Geolocation', 'Calculated host listings count',
  'Host Listings Count', 'Host Total Listings Count','Host Since','Interaction', 'House Rules','Review Scores Communication', 'Review Scores Location',
  'Review Scores Value','Review Scores Cleanliness', 'Review Scores Checkin','Number of Reviews','Review Scores Rating', 'Review Scores Accuracy','City',
   'Country Code','Minimum Nights','Notes', 'Transit','Thumbnail Url','Host Location', 'Host About','Host Verifications','Host Acceptance Rate']


# Hacemos un drop de todas las columnas que aportando información quedan fuera del scope y esas que tienen una gran cantidad de NA
somehow_useful_columns_but_droppable_anyway_and_too_many_missing_values = [ 'Summary', 'Space', 'Description',
       'Neighborhood Overview',  'Access', 'Maximum Nights','Street', 'State', 'Market', 'Smart Location', 'Country',
     'Square Feet', 'Has Availability', 'License', 'Jurisdiction Names','Experiences Offered','Amenities','Cleaning Fee','Security Deposit']
     
print("eliminando columnas...")
data.drop(not_useful_columns, axis=1, inplace=True)
data.drop(somehow_useful_columns_but_droppable_anyway_and_too_many_missing_values, axis=1, inplace=True)
print('data.shape')


print("las columnas que nos quedan y su tipo son:")
data.dtypes
# Out:
# eliminando columnas...
# data.shape
# las columnas que nos quedan y su tipo son:
# Neighbourhood                    object
# Neighbourhood Cleansed           object
# Neighbourhood Group Cleansed     object
# Zipcode                           int64
# Latitude                        float64
# Longitude                       float64
# Property Type                    object
# Room Type                        object
# Accommodates                      int64
# Bathrooms                       float64
# Bedrooms                        float64
# Beds                            float64
# Bed Type                         object
# Price                           float64
# Guests Included                   int64
# Extra People                      int64
# Availability 30                   int64
# Availability 60                   int64
# Availability 90                   int64
# Availability 365                  int64
# Cancellation Policy              object
# Features                         object
# dtype: object

# %% [markdown]
# # Exploramos un poco mas a fondo

# %%
print('Numero de Variables unicas por columnas:')
data.apply(lambda x: len(x.unique()))
# Out:
# Numero de Variables unicas por columnas:
# Neighbourhood                      66
# Neighbourhood Cleansed            125
# Neighbourhood Group Cleansed       21
# Zipcode                            55
# Latitude                        12751
# Longitude                       12751
# Property Type                      22
# Room Type                           3
# Accommodates                       16
# Bathrooms                          17
# Bedrooms                           11
# Beds                               17
# Bed Type                            5
# Price                             276
# Guests Included                    14
# Extra People                       52
# Availability 30                    31
# Availability 60                    61
# Availability 90                    91
# Availability 365                  366
# Cancellation Policy                 5
# Features                           60
# dtype: int64

# %%
print('Observamos el porcentaje de valores nan en cada columna')
data.notnull().mean().mul(100).sort_values(ascending=False)
# Out:
# Observamos el porcentaje de valores nan en cada columna
# Features                        100.000000
# Availability 365                100.000000
# Availability 60                 100.000000
# Availability 30                 100.000000
# Extra People                    100.000000
# Guests Included                 100.000000
# Bed Type                        100.000000
# Neighbourhood Cleansed          100.000000
# Cancellation Policy             100.000000
# Accommodates                    100.000000
# Room Type                       100.000000
# Property Type                   100.000000
# Longitude                       100.000000
# Latitude                        100.000000
# Zipcode                         100.000000
# Neighbourhood Group Cleansed    100.000000
# Availability 90                 100.000000
# Price                            99.937260
# Bedrooms                         99.898047
# Beds                             99.694142
# Bathrooms                        99.623559
# Neighbourhood                    68.355423
# dtype: float64

# %%
# Obtener la media de cada columna numérica
mean_values = data.select_dtypes(include=[np.number]).mean()

# Llenar los valores faltantes con la media
data.fillna(mean_values, inplace=True)

# %% [markdown]
# Tenemos 3 columnas de vecindario, la primera (Neighbourhood) que tiene una gran cantidad de NA, por lo que vamos a eliminarla, luego tenemos neighborhood group cleansed seria la que tiene menos variables unicas ya que neighbourhood cleansed tiene muchas mas, por lo que vamos a eliminar la columna con mas variables unicas y la variables con mas nan.

# %%
data.drop(['Neighbourhood','Neighbourhood Cleansed'], axis=1, inplace=True)

# %%
#Creamos funcio de limpieza de valor Cero sustituido por la media de cada columna
def clean_zeros(df):
    for col in df.select_dtypes(include=['int64', 'float64']):
        mean = df[col].mean()
        df[col] = df[col].replace(0, mean)
    return df
data=clean_zeros(data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Crear matriz de correlación de Pearson
corr_matrix = data.corr(method='pearson')

# Crear mapa de calor
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f', square=True)
plt.title('Matriz de Correlación de Pearson')
plt.show()
print(' Las celdas en rojo/naranja representan correlaciones positivas')
print('Mientras que las celdas en azul representan correlaciones negativas.',)
print('Las celdas con un valor cercano a 1 o -1 indican una alta correlación entre las variables.')
# Out:
#  Las celdas en rojo/naranja representan correlaciones positivas
# Mientras que las celdas en azul representan correlaciones negativas.
# Las celdas con un valor cercano a 1 o -1 indican una alta correlación entre las variables.

# %% [markdown]
# Como podemos ver en la grafica de correlación de Pearson, las variables que tienen una correlación cercana a 1 son bed con accommodates, availability (las 4 col) entre ellas mismas, y Guests included con accommodates.

# %%
print('nos quedamos con availability 360,','bed y','guest included')
data.drop(['Availability 30','Availability 60','Availability 90','Accommodates'], axis=1, inplace=True)
# Out:
# nos quedamos con availability 360, bed y guest included

# %% [markdown]
# Despues de haber limpiado esas columnas queda mucho mas limpia la grafica anterior quedando la corelacion mas alta entre beds y bedrooms

# %%
#Vamos a eliminar las filas con precios mayores a 200
data = data[data['Price'] < 200]
price=data['Price']
data.drop(['Price'], axis=1, inplace=True)
# Out:
# <ipython-input-168-1cd42abd1c12>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['Price'], axis=1, inplace=True)

# %%
print(data.dtypes)
# Out:
# Neighbourhood Group Cleansed     object
# Zipcode                           int64
# Latitude                        float64
# Longitude                       float64
# Property Type                    object
# Room Type                        object
# Bathrooms                       float64
# Bedrooms                        float64
# Beds                            float64
# Bed Type                         object
# Guests Included                   int64
# Extra People                    float64
# Availability 365                float64
# Cancellation Policy              object
# Features                         object
# dtype: object

# %%
print(data.shape)
# Out:
# (12393, 15)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       Neighbourhood Group Cleansed  Zipcode   Latitude  Longitude  \
# 3                           Centro    28005  40.410106  -3.714754
# 4                           Centro    28013  40.416969  -3.709439
# 7                           Centro    28005  40.416514  -3.717843
# 8                           Centro    28013  40.416834  -3.710240
# 9                           Centro    28012  40.413945  -3.705637
# ...                            ...      ...        ...        ...
# 14715                       Centro    28015  40.423878  -3.708321
# 14716                       Centro    28004  40.424988  -3.702364
# 14717                       Centro    28015  40.425166  -3.710959
# 14718                       Centro    28015  40.429196  -3.706743
# 14720                       Centro    28015  40.425181  -3.710374
#
#       Property Type        Room Type  Bathrooms  Bedrooms  Beds  Bed Type  \
# 3         Apartment     Private room        1.0  1.000000   1.0  Real Bed
# 4         Apartment  Entire home/apt        1.0  1.000000   1.0  Real Bed
# 7         Apartment  Entire home/apt        3.0  3.000000   4.0  Real Bed
# 8         Apartment     Private room        2.0  1.000000   1.0  Real Bed
# 9         Apartment     Private room        1.0  1.000000   1.0  Real Bed
# ...             ...              ...        ...       ...   ...       ...
# 14715     Apartment  Entire home/apt        2.0  1.000000   2.0  Real Bed
# 14716     Apartment  Entire home/apt        2.0  2.000000   2.0  Real Bed
# 14717     Apartment  Entire home/apt        1.0  1.293688   1.0  Real Bed
# 14718     Apartment  Entire home/apt        2.0  2.000000   3.0  Real Bed
# 14720     Apartment     Private room        1.0  1.000000   1.0  Real Bed
#
#        Guests Included  Extra People  Availability 365 Cancellation Policy  \
# 3                    1      7.436044               1.0            flexible
# 4                    1      7.436044             320.0              strict
# 7                    6     40.000000             296.0            moderate
# 8                    1      5.000000             341.0              strict
# 9                    1      7.436044             281.0              strict
# ...                ...           ...               ...                 ...
# 14715                2     17.000000             220.0              strict
# 14716                1      7.436044             270.0            flexible
# 14717                1      7.436044             128.0            moderate
# 14718                2     23.000000             273.0            flexible
# 14720                1     10.000000             218.0            flexible
#
#                                                 Features
# 3      Host Has Profile Pic,Host Identity Verified,Is...
# 4      Host Has Profile Pic,Host Identity Verified,Is...
# 7      Host Is Superhost,Host Has Profile Pic,Host Id...
# 8      Host Has Profile Pic,Is Location Exact,Require...
# 9      Host Has Profile Pic,Is Location Exact,Require...
# ...                                                  ...
# 14715  Host Has Profile Pic,Host Identity Verified,Re...
# 14716  Host Has Profile Pic,Host Identity Verified,Is...
# 14717  Host Has Profile Pic,Is Location Exact,Require...
# 14718  Host Has Profile Pic,Is Location Exact,Require...
# 14720  Host Has Profile Pic,Is Location Exact,Require...
#
# [12393 rows x 15 columns]>

# %% [markdown]
# #Dividimos el dataset en train y test.
#
# #Iniciamos Pruebas con diferentes modelos de regresion

# %%
# Import libraries
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# Definimos features
features = ['Guests Included', 'Extra People','Bathrooms', 'Bedrooms', 'Beds', 'Neighbourhood Group Cleansed','Room Type','Availability 365', 'Zipcode','Features']

# Creamos data subset con features
data_subset = data[features ].copy()

# Convertimos la variable categorica a dummies 
data_subset = pd.get_dummies(data_subset)

# Hacemos un Split de data a training y test sets
X_train, X_test, y_train, y_test = train_test_split(data_subset, price, test_size=0.2, random_state=42)

# Scale de features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# Define los hiperparámetros a ajustar
parameters = {'alpha': np.logspace(-3, 3, 7)}

# Crea un objeto de modelo Lasso
lasso_model = Lasso()

# Realiza la búsqueda de hiperparámetros en cuadrícula
grid_search = GridSearchCV(lasso_model, parameters, cv=5)
grid_search.fit(X_train_scaled, y_train)

# Obtiene el mejor conjunto de hiperparámetros y su rendimiento
best_params = grid_search.best_params_
best_score = grid_search.best_score_
best_params
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.711e+03, tolerance: 9.935e+02
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e+04, tolerance: 1.023e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.178e+04, tolerance: 1.014e+03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.855e+03, tolerance: 9.935e+02
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 0.1}

# %%
# Importar y crear una instancia del modelo Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, max_depth=3, random_state=42)

# Ajustar el modelo con los datos de entrenamiento
gbr.fit(X_train, y_train)

# Evaluar el rendimiento del modelo con los datos de prueba
from sklearn.metrics import mean_squared_error, r2_score

y_pred = gbr.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R²:", r2)
# Out:
# MSE: 459.60584753045765
# R²: 0.653550672013493

# %%
# Fit Lasso regression model
lasso = Lasso(alpha=0.1, fit_intercept=True,  precompute=False, copy_X=True, max_iter=1000, tol=0.0001, warm_start=False, positive=False, random_state=42)
lasso.fit(X_train_scaled, y_train)

# Print coefficients of Lasso regression model
coef = pd.Series(lasso.coef_, index=X_train.columns)
print('Lasso picked ' + str(sum(coef != 0)) + ' variables and eliminated the other ' + str(sum(coef == 0)) + ' variables')
print(coef)


from sklearn.metrics import mean_squared_error, r2_score
y_pred = lasso.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('MSE:', mse)
rmse = np.sqrt(mse)
print('RMSE:', rmse)
# Out:
# Lasso picked 72 variables and eliminated the other 19 variables
# Guests Included                                                                                                                    3.885470
# Extra People                                                                                                                       0.227034
# Bathrooms                                                                                                                          3.535236
# Bedrooms                                                                                                                           8.255998
# Beds                                                                                                                               2.163830
#                                                                                                                                      ...
# Features_Host Is Superhost,Host Has Profile Pic,Requires License,Require Guest Profile Picture,Require Guest Phone Verification   -0.015543
# Features_Is Location Exact,Requires License                                                                                        0.306848
# Features_Is Location Exact,Requires License,Instant Bookable                                                                      -0.000000
# Features_Requires License                                                                                                          0.598250
# Features_Requires License,Instant Bookable                                                                                         0.055549
# Length: 91, dtype: float64
# MSE: 624.9738287009118
# RMSE: 24.999476568538626

# %%
#Evaluacion de hiperparametros para random forest
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import validation_curve

# Definir el rango de valores para n_estimators
param_range = [50, 100, 150, 200, 250, 300]

# Usar la función validation_curve para generar los datos de entrenamiento y validación para cada valor de n_estimators
train_scores, test_scores = validation_curve(
    RandomForestRegressor(), X_train, y_train, param_name="n_estimators", param_range=param_range,
    cv=5, scoring="r2", n_jobs=-1)

# Calcular la media y la desviación estándar de los scores para cada valor de n_estimators
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Graficar los resultados de la curva de validación
plt.title("Curva de validación con Random Forest")
plt.xlabel("n_estimators")
plt.ylabel("R²")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(param_range, train_mean, label="Entrenamiento",
             color="darkorange", lw=lw)
plt.fill_between(param_range, train_mean - train_std,
                 train_mean + train_std, alpha=0.2,
                 color="darkorange", lw=lw)
plt.plot(param_range, test_mean, label="Validación cruzada",
             color="navy", lw=lw)
plt.fill_between(param_range, test_mean - test_std,
                 test_mean + test_std, alpha=0.2,
                 color="navy", lw=lw)
plt.legend(loc="best")
plt.show()

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, cross_val_score



# modelo con Random Forest
rf_model = RandomForestRegressor(n_estimators=200, random_state=42)
rf_scores = cross_val_score(rf_model, X_train, y_train, cv=8)
print(f"Random Forest R^2: {rf_scores.mean():.3f} +/- {rf_scores.std():.3f}")

# modelo con Lasso
lasso_model = Lasso(alpha=0.1, random_state=42)
lasso_scores = cross_val_score(lasso_model, X_train, y_train, cv=8)
print(f"Lasso R^2: {lasso_scores.mean():.3f} +/- {lasso_scores.std():.3f}")
# Out:
# Random Forest R^2: 0.659 +/- 0.026
# Lasso R^2: 0.566 +/- 0.028

# %%
import matplotlib.pyplot as plt

# Definir los valores medios y desviaciones estándar de R^2 para cada modelo
random_forest_mean = 0.657
random_forest_std = 0.018
lasso_mean = 0.566
lasso_std = 0.025

# Definir los nombres de los modelos
models = ['Random Forest', 'Lasso']

# Definir los valores medios y desviaciones estándar en una lista
means = [random_forest_mean, lasso_mean]
stds = [random_forest_std, lasso_std]

# Crear el gráfico de barras con barras de error
fig, ax = plt.subplots()
ax.bar(models, means, yerr=stds, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('R^2')
ax.set_ylim(bottom=0.5)  # Para asegurarse de que el eje y comience en 0.5
ax.set_title('Comparación de modelos de regresión')
ax.yaxis.grid(True)

# Mostrar el gráfico
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, price.values, test_size=0.2, shuffle=True,random_state=42)

# %%
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (9914, 15)
# X_test shape: (2479, 15)
# y_train shape: (9914,)
# y_test shape: (2479,)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer


# Seleccione las columnas numéricas y categóricas para su preprocesamiento
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = data.select_dtypes(include=['object']).columns.tolist()

# Creacion preprocesadores para cada tipo de columna
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine los preprocesadores en un solo preprocesador usando ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# %%
final_model = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# Ajustar el modelo combinado en el conjunto de datos de entrenamiento
final_model.fit(X_train, y_train)

# Predecir los precios en el conjunto de datos de prueba utilizando el modelo combinado
y_pred = final_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
# Evaluar el rendimiento del modelo combinado
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"R^2: {r2:.2f}")
# Out:
# RMSE: 21.01
# R^2: 0.67

# %%
import matplotlib.pyplot as plt

# Crear el gráfico de dispersión
plt.scatter(y_test, y_pred)

# etiquetas de los ejes
plt.xlabel('Valor real')
plt.ylabel('Predicción')

plt.show()

# %%
#visualizar el valor real con respecto a la predicción
for gt, pred  in zip(y_test, y_pred):
  error=gt - pred
  print(f'Real: {gt:.2f} Predicho: {pred:.2f}. Error: {error:.2f}')
# Out:
# Real: 130.00 Predicho: 127.97. Error: 2.03
# Real: 24.00 Predicho: 34.75. Error: -10.75
# Real: 31.00 Predicho: 39.26. Error: -8.26
# Real: 49.00 Predicho: 80.79. Error: -31.79
# Real: 49.00 Predicho: 72.51. Error: -23.51
# Real: 14.00 Predicho: 36.33. Error: -22.33
# Real: 110.00 Predicho: 76.21. Error: 33.79
# Real: 80.00 Predicho: 65.50. Error: 14.50
# Real: 20.00 Predicho: 27.27. Error: -7.27
# Real: 24.00 Predicho: 30.87. Error: -6.87
# Real: 130.00 Predicho: 141.50. Error: -11.50
# Real: 35.00 Predicho: 28.94. Error: 6.06
# Real: 90.00 Predicho: 85.93. Error: 4.07
# Real: 49.00 Predicho: 55.23. Error: -6.23
# Real: 65.00 Predicho: 66.72. Error: -1.72
# Real: 15.00 Predicho: 25.05. Error: -10.05
# Real: 42.00 Predicho: 84.47. Error: -42.47
# Real: 22.00 Predicho: 26.34. Error: -4.34
# Real: 50.00 Predicho: 80.68. Error: -30.68
# Real: 55.00 Predicho: 89.52. Error: -34.52
# Real: 160.00 Predicho: 144.89. Error: 15.11
# Real: 35.00 Predicho: 20.09. Error: 14.91
# Real: 100.00 Predicho: 75.13. Error: 24.87
# Real: 18.00 Predicho: 21.26. Error: -3.26
# Real: 98.00 Predicho: 77.08. Error: 20.92
# Real: 99.00 Predicho: 11.16. Error: 87.84
# Real: 38.00 Predicho: 37.24. Error: 0.76
# Real: 50.00 Predicho: 31.68. Error: 18.32
# Real: 25.00 Predicho: 30.29. Error: -5.29
# Real: 104.00 Predicho: 67.23. Error: 36.77
# Real: 90.00 Predicho: 58.44. Error: 31.56
# Real: 69.00 Predicho: 66.28. Error: 2.72
# Real: 56.00 Predicho: 64.12. Error: -8.12
# Real: 13.00 Predicho: 21.15. Error: -8.15
# Real: 90.00 Predicho: 82.19. Error: 7.81
# Real: 75.00 Predicho: 81.76. Error: -6.76
# Real: 50.00 Predicho: 64.53. Error: -14.53
# Real: 39.00 Predicho: 39.87. Error: -0.87
# Real: 55.00 Predicho: 66.66. Error: -11.66
# Real: 70.00 Predicho: 75.42. Error: -5.42
# Real: 67.00 Predicho: 51.64. Error: 15.36
# Real: 40.00 Predicho: 31.78. Error: 8.22
# Real: 60.00 Predicho: 54.30. Error: 5.70
# Real: 100.00 Predicho: 130.88. Error: -30.88
# Real: 30.00 Predicho: 28.73. Error: 1.27
# Real: 80.00 Predicho: 50.39. Error: 29.61
# Real: 65.00 Predicho: 66.56. Error: -1.56
# Real: 90.00 Predicho: 68.35. Error: 21.65
# Real: 70.00 Predicho: 99.32. Error: -29.32
# Real: 27.00 Predicho: 38.92. Error: -11.92
# Real: 75.00 Predicho: 73.88. Error: 1.12
# Real: 110.00 Predicho: 81.80. Error: 28.20
# Real: 75.00 Predicho: 104.78. Error: -29.78
# Real: 44.00 Predicho: 68.52. Error: -24.52
# Real: 42.00 Predicho: 39.00. Error: 3.00
# Real: 31.00 Predicho: 34.28. Error: -3.28
# Real: 125.00 Predicho: 122.57. Error: 2.43
# Real: 65.00 Predicho: 80.35. Error: -15.35
# Real: 22.00 Predicho: 32.09. Error: -10.09
# Real: 58.00 Predicho: 62.51. Error: -4.51
# Real: 50.00 Predicho: 44.86. Error: 5.14
# Real: 43.00 Predicho: 50.72. Error: -7.72
# Real: 75.00 Predicho: 72.37. Error: 2.63
# Real: 85.00 Predicho: 74.11. Error: 10.89
# Real: 44.00 Predicho: 58.54. Error: -14.54
# Real: 49.00 Predicho: 45.92. Error: 3.08
# Real: 70.00 Predicho: 70.69. Error: -0.69
# Real: 59.00 Predicho: 52.71. Error: 6.29
# Real: 147.00 Predicho: 102.29. Error: 44.71
# Real: 165.00 Predicho: 126.14. Error: 38.86
# Real: 98.00 Predicho: 74.61. Error: 23.39
# Real: 75.00 Predicho: 62.77. Error: 12.23
# Real: 120.00 Predicho: 84.31. Error: 35.69
# Real: 35.00 Predicho: 30.02. Error: 4.98
# Real: 67.00 Predicho: 64.95. Error: 2.05
# Real: 10.00 Predicho: 14.32. Error: -4.32
# Real: 100.00 Predicho: 85.54. Error: 14.46
# Real: 45.00 Predicho: 37.43. Error: 7.57
# Real: 16.00 Predicho: 20.41. Error: -4.41
# Real: 165.00 Predicho: 155.07. Error: 9.93
# Real: 85.00 Predicho: 85.22. Error: -0.22
# Real: 65.00 Predicho: 65.56. Error: -0.56
# Real: 50.00 Predicho: 32.91. Error: 17.09
# Real: 22.00 Predicho: 26.48. Error: -4.48
# Real: 70.00 Predicho: 58.88. Error: 11.12
# Real: 40.00 Predicho: 60.78. Error: -20.78
# Real: 25.00 Predicho: 25.61. Error: -0.61
# Real: 120.00 Predicho: 118.80. Error: 1.20
# Real: 43.00 Predicho: 54.96. Error: -11.96
# Real: 21.00 Predicho: 30.78. Error: -9.78
# Real: 53.00 Predicho: 53.03. Error: -0.03
# Real: 55.00 Predicho: 38.23. Error: 16.77
# Real: 15.00 Predicho: 19.39. Error: -4.39
# Real: 50.00 Predicho: 64.16. Error: -14.16
# Real: 36.00 Predicho: 34.76. Error: 1.24
# Real: 50.00 Predicho: 52.42. Error: -2.42
# Real: 35.00 Predicho: 44.85. Error: -9.85
# Real: 40.00 Predicho: 26.12. Error: 13.88
# Real: 43.00 Predicho: 47.86. Error: -4.86
# Real: 50.00 Predicho: 22.57. Error: 27.43
# Real: 33.00 Predicho: 33.14. Error: -0.14
# Real: 110.00 Predicho: 96.48. Error: 13.52
# Real: 26.00 Predicho: 30.61. Error: -4.61
# Real: 52.00 Predicho: 51.26. Error: 0.74
# Real: 95.00 Predicho: 79.92. Error: 15.08
# Real: 60.00 Predicho: 70.65. Error: -10.65
# Real: 50.00 Predicho: 53.49. Error: -3.49
# Real: 42.00 Predicho: 49.59. Error: -7.59
# Real: 100.00 Predicho: 67.55. Error: 32.45
# Real: 30.00 Predicho: 39.35. Error: -9.35
# Real: 26.00 Predicho: 21.68. Error: 4.32
# Real: 30.00 Predicho: 21.69. Error: 8.31
# Real: 70.00 Predicho: 68.53. Error: 1.47
# Real: 33.00 Predicho: 23.83. Error: 9.17
# Real: 50.00 Predicho: 63.55. Error: -13.55
# Real: 75.00 Predicho: 54.07. Error: 20.93
# Real: 18.00 Predicho: 29.68. Error: -11.68
# Real: 90.00 Predicho: 36.14. Error: 53.86
# Real: 25.00 Predicho: 22.89. Error: 2.11
# Real: 55.00 Predicho: 66.23. Error: -11.23
# Real: 40.00 Predicho: 41.67. Error: -1.67
# Real: 35.00 Predicho: 36.33. Error: -1.33
# Real: 85.00 Predicho: 94.97. Error: -9.97
# Real: 49.00 Predicho: 70.55. Error: -21.55
# Real: 30.00 Predicho: 33.58. Error: -3.58
# Real: 33.00 Predicho: 19.05. Error: 13.95
# Real: 107.00 Predicho: 104.20. Error: 2.80
# Real: 50.00 Predicho: 57.62. Error: -7.62
# Real: 100.00 Predicho: 90.69. Error: 9.31
# Real: 75.00 Predicho: 64.49. Error: 10.51
# Real: 60.00 Predicho: 61.40. Error: -1.40
# Real: 60.00 Predicho: 75.81. Error: -15.81
# Real: 29.00 Predicho: 27.48. Error: 1.52
# Real: 40.00 Predicho: 28.41. Error: 11.59
# Real: 65.00 Predicho: 70.31. Error: -5.31
# Real: 110.00 Predicho: 142.07. Error: -32.07
# Real: 24.00 Predicho: 30.83. Error: -6.83
# Real: 75.00 Predicho: 72.94. Error: 2.06
# Real: 48.00 Predicho: 55.41. Error: -7.41
# Real: 17.00 Predicho: 20.67. Error: -3.67
# Real: 18.00 Predicho: 31.78. Error: -13.78
# Real: 45.00 Predicho: 29.96. Error: 15.04
# Real: 100.00 Predicho: 69.95. Error: 30.05
# Real: 19.00 Predicho: 18.52. Error: 0.48
# Real: 62.00 Predicho: 59.86. Error: 2.14
# Real: 80.00 Predicho: 86.77. Error: -6.77
# Real: 120.00 Predicho: 111.66. Error: 8.34
# Real: 15.00 Predicho: 18.87. Error: -3.87
# Real: 19.00 Predicho: 18.83. Error: 0.17
# Real: 15.00 Predicho: 25.65. Error: -10.65
# Real: 150.00 Predicho: 65.08. Error: 84.92
# Real: 60.00 Predicho: 54.99. Error: 5.01
# Real: 125.00 Predicho: 60.96. Error: 64.04
# Real: 39.00 Predicho: 43.66. Error: -4.66
# Real: 112.00 Predicho: 94.11. Error: 17.89
# Real: 25.00 Predicho: 31.28. Error: -6.28
# Real: 65.00 Predicho: 59.06. Error: 5.94
# Real: 20.00 Predicho: 41.64. Error: -21.64
# Real: 160.00 Predicho: 100.22. Error: 59.78
# Real: 15.00 Predicho: 17.65. Error: -2.65
# Real: 39.00 Predicho: 36.07. Error: 2.93
# Real: 65.00 Predicho: 76.64. Error: -11.64
# Real: 40.00 Predicho: 52.41. Error: -12.41
# Real: 20.00 Predicho: 27.75. Error: -7.75
# Real: 60.00 Predicho: 67.03. Error: -7.03
# Real: 136.00 Predicho: 108.57. Error: 27.43
# Real: 45.00 Predicho: 32.70. Error: 12.30
# Real: 20.00 Predicho: 21.56. Error: -1.56
# Real: 195.00 Predicho: 97.32. Error: 97.68
# Real: 74.00 Predicho: 66.27. Error: 7.73
# Real: 26.00 Predicho: 32.54. Error: -6.54
# Real: 23.00 Predicho: 27.52. Error: -4.52
# Real: 31.00 Predicho: 29.71. Error: 1.29
# Real: 55.00 Predicho: 59.29. Error: -4.29
# Real: 40.00 Predicho: 36.03. Error: 3.97
# Real: 26.00 Predicho: 33.73. Error: -7.73
# Real: 40.00 Predicho: 86.95. Error: -46.95
# Real: 80.00 Predicho: 64.89. Error: 15.11
# Real: 20.00 Predicho: 26.41. Error: -6.41
# Real: 155.00 Predicho: 147.66. Error: 7.34
# Real: 110.00 Predicho: 121.50. Error: -11.50
# Real: 61.00 Predicho: 83.13. Error: -22.13
# Real: 25.00 Predicho: 29.19. Error: -4.19
# Real: 25.00 Predicho: 23.84. Error: 1.16
# Real: 40.00 Predicho: 47.00. Error: -7.00
# Real: 85.00 Predicho: 72.49. Error: 12.51
# Real: 60.00 Predicho: 70.64. Error: -10.64
# Real: 59.00 Predicho: 39.25. Error: 19.75
# Real: 80.00 Predicho: 77.62. Error: 2.38
# Real: 23.00 Predicho: 23.82. Error: -0.82
# Real: 60.00 Predicho: 66.71. Error: -6.71
# Real: 50.00 Predicho: 66.63. Error: -16.63
# Real: 50.00 Predicho: 59.66. Error: -9.66
# Real: 28.00 Predicho: 19.27. Error: 8.73
# Real: 60.00 Predicho: 60.22. Error: -0.22
# Real: 60.00 Predicho: 53.15. Error: 6.85
# Real: 36.00 Predicho: 33.86. Error: 2.14
# Real: 49.00 Predicho: 42.01. Error: 6.99
# Real: 35.00 Predicho: 38.03. Error: -3.03
# Real: 95.00 Predicho: 91.65. Error: 3.35
# Real: 53.00 Predicho: 63.55. Error: -10.55
# Real: 70.00 Predicho: 93.00. Error: -23.00
# Real: 100.00 Predicho: 91.45. Error: 8.55
# Real: 49.00 Predicho: 34.61. Error: 14.39
# Real: 60.00 Predicho: 58.14. Error: 1.86
# Real: 80.00 Predicho: 55.46. Error: 24.54
# Real: 24.00 Predicho: 29.83. Error: -5.83
# Real: 12.00 Predicho: 20.84. Error: -8.84
# Real: 40.00 Predicho: 54.67. Error: -14.67
# Real: 65.00 Predicho: 35.74. Error: 29.26
# Real: 110.00 Predicho: 91.24. Error: 18.76
# Real: 45.00 Predicho: 31.80. Error: 13.20
# Real: 90.00 Predicho: 74.28. Error: 15.72
# Real: 76.00 Predicho: 88.80. Error: -12.80
# Real: 45.00 Predicho: 43.72. Error: 1.28
# Real: 95.00 Predicho: 87.46. Error: 7.54
# Real: 55.00 Predicho: 70.80. Error: -15.80
# Real: 90.00 Predicho: 67.41. Error: 22.59
# Real: 62.00 Predicho: 71.08. Error: -9.08
# Real: 160.00 Predicho: 92.19. Error: 67.81
# Real: 35.00 Predicho: 32.35. Error: 2.65
# Real: 28.00 Predicho: 29.30. Error: -1.30
# Real: 39.00 Predicho: 79.64. Error: -40.64
# Real: 25.00 Predicho: 32.92. Error: -7.92
# Real: 26.00 Predicho: 31.57. Error: -5.57
# Real: 68.00 Predicho: 66.62. Error: 1.38
# Real: 50.00 Predicho: 52.59. Error: -2.59
# Real: 45.00 Predicho: 51.27. Error: -6.27
# Real: 90.00 Predicho: 67.59. Error: 22.41
# Real: 23.00 Predicho: 20.91. Error: 2.09
# Real: 58.00 Predicho: 71.86. Error: -13.86
# Real: 25.00 Predicho: 23.26. Error: 1.74
# Real: 20.00 Predicho: 39.59. Error: -19.59
# Real: 90.00 Predicho: 82.84. Error: 7.16
# Real: 60.00 Predicho: 66.40. Error: -6.40
# Real: 34.00 Predicho: 68.21. Error: -34.21
# Real: 139.00 Predicho: 116.54. Error: 22.46
# Real: 70.00 Predicho: 64.80. Error: 5.20
# Real: 60.00 Predicho: 65.38. Error: -5.38
# Real: 26.00 Predicho: 31.40. Error: -5.40
# Real: 120.00 Predicho: 107.35. Error: 12.65
# Real: 35.00 Predicho: 28.89. Error: 6.11
# Real: 50.00 Predicho: 22.50. Error: 27.50
# Real: 20.00 Predicho: 24.76. Error: -4.76
# Real: 40.00 Predicho: 21.89. Error: 18.11
# Real: 45.00 Predicho: 63.51. Error: -18.51
# Real: 95.00 Predicho: 75.63. Error: 19.37
# Real: 150.00 Predicho: 121.25. Error: 28.75
# Real: 190.00 Predicho: 28.22. Error: 161.78
# Real: 140.00 Predicho: 67.11. Error: 72.89
# Real: 49.00 Predicho: 64.94. Error: -15.94
# Real: 100.00 Predicho: 90.94. Error: 9.06
# Real: 65.96 Predicho: 93.37. Error: -27.41
# Real: 30.00 Predicho: 33.02. Error: -3.02
# Real: 28.00 Predicho: 28.68. Error: -0.68
# Real: 160.00 Predicho: 148.10. Error: 11.90
# Real: 100.00 Predicho: 115.86. Error: -15.86
# Real: 110.00 Predicho: 45.93. Error: 64.07
# Real: 90.00 Predicho: 60.61. Error: 29.39
# Real: 90.00 Predicho: 92.85. Error: -2.85
# Real: 65.00 Predicho: 38.74. Error: 26.26
# Real: 60.00 Predicho: 72.70. Error: -12.70
# Real: 150.00 Predicho: 117.72. Error: 32.28
# Real: 22.00 Predicho: 68.30. Error: -46.30
# Real: 69.00 Predicho: 96.24. Error: -27.24
# Real: 25.00 Predicho: 42.88. Error: -17.88
# Real: 26.00 Predicho: 35.35. Error: -9.35
# Real: 40.00 Predicho: 44.99. Error: -4.99
# Real: 120.00 Predicho: 127.77. Error: -7.77
# Real: 40.00 Predicho: 73.99. Error: -33.99
# Real: 20.00 Predicho: 26.05. Error: -6.05
# Real: 50.00 Predicho: 55.05. Error: -5.05
# Real: 125.00 Predicho: 114.60. Error: 10.40
# Real: 65.00 Predicho: 62.18. Error: 2.82
# Real: 83.00 Predicho: 82.76. Error: 0.24
# Real: 165.00 Predicho: 158.02. Error: 6.98
# Real: 98.00 Predicho: 100.77. Error: -2.77
# Real: 25.00 Predicho: 41.40. Error: -16.40
# Real: 23.00 Predicho: 32.05. Error: -9.05
# Real: 155.00 Predicho: 153.43. Error: 1.57
# Real: 48.00 Predicho: 57.06. Error: -9.06
# Real: 55.00 Predicho: 56.19. Error: -1.19
# Real: 57.00 Predicho: 81.89. Error: -24.89
# Real: 90.00 Predicho: 85.99. Error: 4.01
# Real: 89.00 Predicho: 84.56. Error: 4.44
# Real: 25.00 Predicho: 22.74. Error: 2.26
# Real: 20.00 Predicho: 17.23. Error: 2.77
# Real: 42.00 Predicho: 22.79. Error: 19.21
# Real: 60.00 Predicho: 58.76. Error: 1.24
# Real: 50.00 Predicho: 60.12. Error: -10.12
# Real: 32.00 Predicho: 35.54. Error: -3.54
# Real: 20.00 Predicho: 30.98. Error: -10.98
# Real: 25.00 Predicho: 44.55. Error: -19.55
# Real: 77.00 Predicho: 63.56. Error: 13.44
# Real: 20.00 Predicho: 20.45. Error: -0.45
# Real: 80.00 Predicho: 58.44. Error: 21.56
# Real: 90.00 Predicho: 77.16. Error: 12.84
# Real: 80.00 Predicho: 85.61. Error: -5.61
# Real: 50.00 Predicho: 64.43. Error: -14.43
# Real: 65.00 Predicho: 62.95. Error: 2.05
# Real: 20.00 Predicho: 29.51. Error: -9.51
# Real: 23.00 Predicho: 25.81. Error: -2.81
# Real: 50.00 Predicho: 35.54. Error: 14.46
# Real: 100.00 Predicho: 80.48. Error: 19.52
# Real: 15.00 Predicho: 32.62. Error: -17.62
# Real: 35.00 Predicho: 38.42. Error: -3.42
# Real: 90.00 Predicho: 60.33. Error: 29.67
# Real: 60.00 Predicho: 47.92. Error: 12.08
# Real: 30.00 Predicho: 27.53. Error: 2.47
# Real: 85.00 Predicho: 116.28. Error: -31.28
# Real: 138.00 Predicho: 113.90. Error: 24.10
# Real: 65.00 Predicho: 46.80. Error: 18.20
# Real: 153.00 Predicho: 130.56. Error: 22.44
# Real: 25.00 Predicho: 29.87. Error: -4.87
# Real: 145.00 Predicho: 93.28. Error: 51.72
# Real: 25.00 Predicho: 25.36. Error: -0.36
# Real: 69.00 Predicho: 99.82. Error: -30.82
# Real: 45.00 Predicho: 48.35. Error: -3.35
# Real: 64.00 Predicho: 35.13. Error: 28.87
# Real: 70.00 Predicho: 28.59. Error: 41.41
# Real: 90.00 Predicho: 104.12. Error: -14.12
# Real: 90.00 Predicho: 142.41. Error: -52.41
# Real: 30.00 Predicho: 33.59. Error: -3.59
# Real: 47.00 Predicho: 52.22. Error: -5.22
# Real: 65.00 Predicho: 73.09. Error: -8.09
# Real: 39.00 Predicho: 45.87. Error: -6.87
# Real: 105.00 Predicho: 71.77. Error: 33.23
# Real: 75.00 Predicho: 74.75. Error: 0.25
# Real: 79.00 Predicho: 62.36. Error: 16.64
# Real: 70.00 Predicho: 71.73. Error: -1.73
# Real: 45.00 Predicho: 47.82. Error: -2.82
# Real: 190.00 Predicho: 126.95. Error: 63.05
# Real: 105.00 Predicho: 77.08. Error: 27.92
# Real: 25.00 Predicho: 20.97. Error: 4.03
# Real: 45.00 Predicho: 64.57. Error: -19.57
# Real: 86.00 Predicho: 75.31. Error: 10.69
# Real: 43.00 Predicho: 33.19. Error: 9.81
# Real: 17.00 Predicho: 16.65. Error: 0.35
# Real: 120.00 Predicho: 90.03. Error: 29.97
# Real: 45.00 Predicho: 50.39. Error: -5.39
# Real: 30.00 Predicho: 40.18. Error: -10.18
# Real: 74.00 Predicho: 70.68. Error: 3.32
# Real: 43.00 Predicho: 31.31. Error: 11.69
# Real: 45.00 Predicho: 43.25. Error: 1.75
# Real: 49.00 Predicho: 38.21. Error: 10.79
# Real: 120.00 Predicho: 41.79. Error: 78.21
# Real: 26.00 Predicho: 33.70. Error: -7.70
# Real: 29.00 Predicho: 23.60. Error: 5.40
# Real: 58.00 Predicho: 69.23. Error: -11.23
# Real: 80.00 Predicho: 64.94. Error: 15.06
# Real: 63.00 Predicho: 67.17. Error: -4.17
# Real: 25.00 Predicho: 18.50. Error: 6.50
# Real: 25.00 Predicho: 29.46. Error: -4.46
# Real: 49.00 Predicho: 69.65. Error: -20.65
# Real: 55.00 Predicho: 71.03. Error: -16.03
# Real: 50.00 Predicho: 66.52. Error: -16.52
# Real: 20.00 Predicho: 30.66. Error: -10.66
# Real: 19.00 Predicho: 26.60. Error: -7.60
# Real: 60.00 Predicho: 73.18. Error: -13.18
# Real: 19.00 Predicho: 21.57. Error: -2.57
# Real: 32.00 Predicho: 27.73. Error: 4.27
# Real: 70.00 Predicho: 56.97. Error: 13.03
# Real: 29.00 Predicho: 34.17. Error: -5.17
# Real: 35.00 Predicho: 45.85. Error: -10.85
# Real: 77.00 Predicho: 57.43. Error: 19.57
# Real: 85.00 Predicho: 92.22. Error: -7.22
# Real: 45.00 Predicho: 49.82. Error: -4.82
# Real: 65.00 Predicho: 68.62. Error: -3.62
# Real: 28.00 Predicho: 22.08. Error: 5.92
# Real: 35.00 Predicho: 53.57. Error: -18.57
# Real: 43.00 Predicho: 75.10. Error: -32.10
# Real: 38.00 Predicho: 35.33. Error: 2.67
# Real: 25.00 Predicho: 39.74. Error: -14.74
# Real: 56.00 Predicho: 60.04. Error: -4.04
# Real: 74.00 Predicho: 28.28. Error: 45.72
# Real: 60.00 Predicho: 69.17. Error: -9.17
# Real: 85.00 Predicho: 121.47. Error: -36.47
# Real: 138.00 Predicho: 138.53. Error: -0.53
# Real: 17.00 Predicho: 28.41. Error: -11.41
# Real: 65.00 Predicho: 57.97. Error: 7.03
# Real: 80.00 Predicho: 65.07. Error: 14.93
# Real: 70.00 Predicho: 73.56. Error: -3.56
# Real: 90.00 Predicho: 106.47. Error: -16.47
# Real: 85.00 Predicho: 86.04. Error: -1.04
# Real: 34.00 Predicho: 36.57. Error: -2.57
# Real: 50.00 Predicho: 45.11. Error: 4.89
# Real: 75.00 Predicho: 69.48. Error: 5.52
# Real: 190.00 Predicho: 144.78. Error: 45.22
# Real: 128.00 Predicho: 139.07. Error: -11.07
# Real: 14.00 Predicho: 19.24. Error: -5.24
# Real: 16.00 Predicho: 16.23. Error: -0.23
# Real: 18.00 Predicho: 23.34. Error: -5.34
# Real: 84.00 Predicho: 122.66. Error: -38.66
# Real: 75.00 Predicho: 76.63. Error: -1.63
# Real: 60.00 Predicho: 35.91. Error: 24.09
# Real: 60.00 Predicho: 35.85. Error: 24.15
# Real: 47.00 Predicho: 64.78. Error: -17.78
# Real: 35.00 Predicho: 24.08. Error: 10.92
# Real: 50.00 Predicho: 65.58. Error: -15.58
# Real: 40.00 Predicho: 34.39. Error: 5.61
# Real: 24.00 Predicho: 16.12. Error: 7.88
# Real: 80.00 Predicho: 108.78. Error: -28.78
# Real: 20.00 Predicho: 24.91. Error: -4.91
# Real: 185.00 Predicho: 75.26. Error: 109.74
# Real: 20.00 Predicho: 38.50. Error: -18.50
# Real: 95.00 Predicho: 93.36. Error: 1.64
# Real: 22.00 Predicho: 28.98. Error: -6.98
# Real: 85.00 Predicho: 82.29. Error: 2.71
# Real: 42.00 Predicho: 52.65. Error: -10.65
# Real: 38.00 Predicho: 26.85. Error: 11.15
# Real: 67.00 Predicho: 66.79. Error: 0.21
# Real: 16.00 Predicho: 25.64. Error: -9.64
# Real: 82.00 Predicho: 69.59. Error: 12.41
# Real: 18.00 Predicho: 20.53. Error: -2.53
# Real: 85.00 Predicho: 96.43. Error: -11.43
# Real: 79.00 Predicho: 87.95. Error: -8.95
# Real: 99.00 Predicho: 87.47. Error: 11.53
# Real: 30.00 Predicho: 20.98. Error: 9.02
# Real: 60.00 Predicho: 55.24. Error: 4.76
# Real: 78.00 Predicho: 62.28. Error: 15.72
# Real: 60.00 Predicho: 33.61. Error: 26.39
# Real: 70.00 Predicho: 83.78. Error: -13.78
# Real: 42.00 Predicho: 63.33. Error: -21.33
# Real: 23.00 Predicho: 33.34. Error: -10.34
# Real: 14.00 Predicho: 19.40. Error: -5.40
# Real: 40.00 Predicho: 38.17. Error: 1.83
# Real: 95.00 Predicho: 68.75. Error: 26.25
# Real: 140.00 Predicho: 67.35. Error: 72.65
# Real: 18.00 Predicho: 27.35. Error: -9.35
# Real: 40.00 Predicho: 37.55. Error: 2.45
# Real: 22.00 Predicho: 30.25. Error: -8.25
# Real: 90.00 Predicho: 97.96. Error: -7.96
# Real: 60.00 Predicho: 55.34. Error: 4.66
# Real: 85.00 Predicho: 72.03. Error: 12.97
# Real: 35.00 Predicho: 40.18. Error: -5.18
# Real: 80.00 Predicho: 90.92. Error: -10.92
# Real: 24.00 Predicho: 33.09. Error: -9.09
# Real: 69.00 Predicho: 72.38. Error: -3.38
# Real: 95.00 Predicho: 82.05. Error: 12.95
# Real: 70.00 Predicho: 112.00. Error: -42.00
# Real: 65.00 Predicho: 78.15. Error: -13.15
# Real: 50.00 Predicho: 63.73. Error: -13.73
# Real: 70.00 Predicho: 66.49. Error: 3.51
# Real: 35.00 Predicho: 46.09. Error: -11.09
# Real: 83.00 Predicho: 75.20. Error: 7.80
# Real: 50.00 Predicho: 53.32. Error: -3.32
# Real: 59.00 Predicho: 71.70. Error: -12.70
# Real: 140.00 Predicho: 83.34. Error: 56.66
# Real: 49.00 Predicho: 70.47. Error: -21.47
# Real: 113.00 Predicho: 82.70. Error: 30.30
# Real: 148.00 Predicho: 115.16. Error: 32.84
# Real: 60.00 Predicho: 61.42. Error: -1.42
# Real: 29.00 Predicho: 33.50. Error: -4.50
# Real: 36.00 Predicho: 50.96. Error: -14.96
# Real: 110.00 Predicho: 86.43. Error: 23.57
# Real: 39.00 Predicho: 48.72. Error: -9.72
# Real: 99.00 Predicho: 102.16. Error: -3.16
# Real: 42.00 Predicho: 56.43. Error: -14.43
# Real: 36.00 Predicho: 34.08. Error: 1.92
# Real: 50.00 Predicho: 60.08. Error: -10.08
# Real: 45.00 Predicho: 61.32. Error: -16.32
# Real: 130.00 Predicho: 65.01. Error: 64.99
# Real: 45.00 Predicho: 46.44. Error: -1.44
# Real: 125.00 Predicho: 94.07. Error: 30.93
# Real: 85.00 Predicho: 75.93. Error: 9.07
# Real: 35.00 Predicho: 37.64. Error: -2.64
# Real: 55.00 Predicho: 74.41. Error: -19.41
# Real: 150.00 Predicho: 137.63. Error: 12.37
# Real: 29.00 Predicho: 22.52. Error: 6.48
# Real: 60.00 Predicho: 101.73. Error: -41.73
# Real: 58.00 Predicho: 61.95. Error: -3.95
# Real: 90.00 Predicho: 64.31. Error: 25.69
# Real: 66.00 Predicho: 75.85. Error: -9.85
# Real: 16.00 Predicho: 19.10. Error: -3.10
# Real: 30.00 Predicho: 30.00. Error: 0.00
# Real: 25.00 Predicho: 31.52. Error: -6.52
# Real: 21.00 Predicho: 24.49. Error: -3.49
# Real: 85.00 Predicho: 116.55. Error: -31.55
# Real: 75.00 Predicho: 84.11. Error: -9.11
# Real: 35.00 Predicho: 52.28. Error: -17.28
# Real: 100.00 Predicho: 118.78. Error: -18.78
# Real: 18.00 Predicho: 21.93. Error: -3.93
# Real: 63.00 Predicho: 48.53. Error: 14.47
# Real: 38.00 Predicho: 30.69. Error: 7.31
# Real: 100.00 Predicho: 102.38. Error: -2.38
# Real: 100.00 Predicho: 61.63. Error: 38.37
# Real: 150.00 Predicho: 138.79. Error: 11.21
# Real: 92.00 Predicho: 115.95. Error: -23.95
# Real: 75.00 Predicho: 70.20. Error: 4.80
# Real: 26.00 Predicho: 28.51. Error: -2.51
# Real: 15.00 Predicho: 30.88. Error: -15.88
# Real: 55.00 Predicho: 69.04. Error: -14.04
# Real: 50.00 Predicho: 69.97. Error: -19.97
# Real: 36.00 Predicho: 35.04. Error: 0.96
# Real: 48.00 Predicho: 31.72. Error: 16.28
# Real: 79.00 Predicho: 61.04. Error: 17.96
# Real: 83.00 Predicho: 78.44. Error: 4.56
# Real: 90.00 Predicho: 65.96. Error: 24.04
# Real: 64.00 Predicho: 89.67. Error: -25.67
# Real: 79.00 Predicho: 66.20. Error: 12.80
# Real: 65.00 Predicho: 50.01. Error: 14.99
# Real: 110.00 Predicho: 117.91. Error: -7.91
# Real: 99.00 Predicho: 87.12. Error: 11.88
# Real: 17.00 Predicho: 26.64. Error: -9.64
# Real: 69.00 Predicho: 69.56. Error: -0.56
# Real: 80.00 Predicho: 134.43. Error: -54.43
# Real: 50.00 Predicho: 62.38. Error: -12.38
# Real: 70.00 Predicho: 64.90. Error: 5.10
# Real: 50.00 Predicho: 70.93. Error: -20.93
# Real: 30.00 Predicho: 41.80. Error: -11.80
# Real: 23.00 Predicho: 25.70. Error: -2.70
# Real: 50.00 Predicho: 33.11. Error: 16.89
# Real: 80.00 Predicho: 73.84. Error: 6.16
# Real: 70.00 Predicho: 101.83. Error: -31.83
# Real: 80.00 Predicho: 74.96. Error: 5.04
# Real: 125.00 Predicho: 71.51. Error: 53.49
# Real: 25.00 Predicho: 24.92. Error: 0.08
# Real: 25.00 Predicho: 34.20. Error: -9.20
# Real: 45.00 Predicho: 50.01. Error: -5.01
# Real: 12.00 Predicho: 32.83. Error: -20.83
# Real: 49.00 Predicho: 101.78. Error: -52.78
# Real: 55.00 Predicho: 31.52. Error: 23.48
# Real: 70.00 Predicho: 104.39. Error: -34.39
# Real: 49.00 Predicho: 80.07. Error: -31.07
# Real: 32.00 Predicho: 38.75. Error: -6.75
# Real: 24.00 Predicho: 30.70. Error: -6.70
# Real: 29.00 Predicho: 29.18. Error: -0.18
# Real: 45.00 Predicho: 50.32. Error: -5.32
# Real: 160.00 Predicho: 119.63. Error: 40.37
# Real: 20.00 Predicho: 24.99. Error: -4.99
# Real: 45.00 Predicho: 75.80. Error: -30.80
# Real: 85.00 Predicho: 82.88. Error: 2.12
# Real: 60.00 Predicho: 45.33. Error: 14.67
# Real: 140.00 Predicho: 129.47. Error: 10.53
# Real: 49.00 Predicho: 57.99. Error: -8.99
# Real: 85.00 Predicho: 91.21. Error: -6.21
# Real: 100.00 Predicho: 94.47. Error: 5.53
# Real: 55.00 Predicho: 66.87. Error: -11.87
# Real: 18.00 Predicho: 18.71. Error: -0.71
# Real: 170.00 Predicho: 106.21. Error: 63.79
# Real: 50.00 Predicho: 62.19. Error: -12.19
# Real: 60.00 Predicho: 94.04. Error: -34.04
# Real: 49.00 Predicho: 53.74. Error: -4.74
# Real: 50.00 Predicho: 56.12. Error: -6.12
# Real: 18.00 Predicho: 28.46. Error: -10.46
# Real: 27.00 Predicho: 24.20. Error: 2.80
# Real: 82.00 Predicho: 66.65. Error: 15.35
# Real: 49.00 Predicho: 48.18. Error: 0.82
# Real: 25.00 Predicho: 19.83. Error: 5.17
# Real: 50.00 Predicho: 47.41. Error: 2.59
# Real: 50.00 Predicho: 74.14. Error: -24.14
# Real: 120.00 Predicho: 88.47. Error: 31.53
# Real: 65.00 Predicho: 57.92. Error: 7.08
# Real: 45.00 Predicho: 69.47. Error: -24.47
# Real: 58.00 Predicho: 42.29. Error: 15.71
# Real: 20.00 Predicho: 41.53. Error: -21.53
# Real: 50.00 Predicho: 66.06. Error: -16.06
# Real: 19.00 Predicho: 23.82. Error: -4.82
# Real: 55.00 Predicho: 52.97. Error: 2.03
# Real: 145.00 Predicho: 113.32. Error: 31.68
# Real: 42.00 Predicho: 34.14. Error: 7.86
# Real: 15.00 Predicho: 17.23. Error: -2.23
# Real: 75.00 Predicho: 27.07. Error: 47.93
# Real: 81.00 Predicho: 92.05. Error: -11.05
# Real: 59.00 Predicho: 39.38. Error: 19.62
# Real: 74.00 Predicho: 97.88. Error: -23.88
# Real: 50.00 Predicho: 34.05. Error: 15.95
# Real: 45.00 Predicho: 48.36. Error: -3.36
# Real: 160.00 Predicho: 72.98. Error: 87.02
# Real: 80.00 Predicho: 74.08. Error: 5.92
# Real: 70.00 Predicho: 60.69. Error: 9.31
# Real: 99.00 Predicho: 93.38. Error: 5.62
# Real: 105.00 Predicho: 76.62. Error: 28.38
# Real: 120.00 Predicho: 129.61. Error: -9.61
# Real: 80.00 Predicho: 84.83. Error: -4.83
# Real: 42.00 Predicho: 67.40. Error: -25.40
# Real: 45.00 Predicho: 52.99. Error: -7.99
# Real: 20.00 Predicho: 22.75. Error: -2.75
# Real: 20.00 Predicho: 33.58. Error: -13.58
# Real: 85.00 Predicho: 60.18. Error: 24.82
# Real: 29.00 Predicho: 28.91. Error: 0.09
# Real: 68.00 Predicho: 58.66. Error: 9.34
# Real: 18.00 Predicho: 25.67. Error: -7.67
# Real: 90.00 Predicho: 79.72. Error: 10.28
# Real: 20.00 Predicho: 30.01. Error: -10.01
# Real: 40.00 Predicho: 51.66. Error: -11.66
# Real: 18.00 Predicho: 22.16. Error: -4.16
# Real: 71.00 Predicho: 78.76. Error: -7.76
# Real: 55.00 Predicho: 63.36. Error: -8.36
# Real: 20.00 Predicho: 24.77. Error: -4.77
# Real: 45.00 Predicho: 32.92. Error: 12.08
# Real: 170.00 Predicho: 147.32. Error: 22.68
# Real: 20.00 Predicho: 33.52. Error: -13.52
# Real: 95.00 Predicho: 110.50. Error: -15.50
# Real: 95.00 Predicho: 69.10. Error: 25.90
# Real: 50.00 Predicho: 58.96. Error: -8.96
# Real: 68.00 Predicho: 82.10. Error: -14.10
# Real: 20.00 Predicho: 32.15. Error: -12.15
# Real: 16.00 Predicho: 14.89. Error: 1.11
# Real: 55.00 Predicho: 71.58. Error: -16.58
# Real: 40.00 Predicho: 37.23. Error: 2.77
# Real: 89.00 Predicho: 69.22. Error: 19.78
# Real: 60.00 Predicho: 43.67. Error: 16.33
# Real: 20.00 Predicho: 23.00. Error: -3.00
# Real: 25.00 Predicho: 26.04. Error: -1.04
# Real: 130.00 Predicho: 126.74. Error: 3.26
# Real: 60.00 Predicho: 51.20. Error: 8.80
# Real: 31.00 Predicho: 36.09. Error: -5.09
# Real: 66.00 Predicho: 87.03. Error: -21.03
# Real: 25.00 Predicho: 24.12. Error: 0.88
# Real: 64.00 Predicho: 70.71. Error: -6.71
# Real: 21.00 Predicho: 29.48. Error: -8.48
# Real: 49.00 Predicho: 64.46. Error: -15.46
# Real: 45.00 Predicho: 56.12. Error: -11.12
# Real: 60.00 Predicho: 114.07. Error: -54.07
# Real: 20.00 Predicho: 21.08. Error: -1.08
# Real: 35.00 Predicho: 56.89. Error: -21.89
# Real: 95.00 Predicho: 81.33. Error: 13.67
# Real: 24.00 Predicho: 28.38. Error: -4.38
# Real: 60.00 Predicho: 85.08. Error: -25.08
# Real: 20.00 Predicho: 27.23. Error: -7.23
# Real: 188.00 Predicho: 92.63. Error: 95.37
# Real: 15.00 Predicho: 19.83. Error: -4.83
# Real: 110.00 Predicho: 127.04. Error: -17.04
# Real: 35.00 Predicho: 37.09. Error: -2.09
# Real: 25.00 Predicho: 40.97. Error: -15.97
# Real: 50.00 Predicho: 50.39. Error: -0.39
# Real: 22.00 Predicho: 42.48. Error: -20.48
# Real: 55.00 Predicho: 78.79. Error: -23.79
# Real: 90.00 Predicho: 57.52. Error: 32.48
# Real: 39.00 Predicho: 64.47. Error: -25.47
# Real: 95.00 Predicho: 116.56. Error: -21.56
# Real: 55.00 Predicho: 67.13. Error: -12.13
# Real: 48.00 Predicho: 57.36. Error: -9.36
# Real: 75.00 Predicho: 80.80. Error: -5.80
# Real: 63.00 Predicho: 69.35. Error: -6.35
# Real: 40.00 Predicho: 41.53. Error: -1.53
# Real: 77.00 Predicho: 88.45. Error: -11.45
# Real: 30.00 Predicho: 30.68. Error: -0.68
# Real: 24.00 Predicho: 27.65. Error: -3.65
# Real: 70.00 Predicho: 69.01. Error: 0.99
# Real: 79.00 Predicho: 64.63. Error: 14.37
# Real: 60.00 Predicho: 35.78. Error: 24.22
# Real: 50.00 Predicho: 56.81. Error: -6.81
# Real: 36.00 Predicho: 31.10. Error: 4.90
# Real: 110.00 Predicho: 75.95. Error: 34.05
# Real: 47.00 Predicho: 59.67. Error: -12.67
# Real: 75.00 Predicho: 80.65. Error: -5.65
# Real: 50.00 Predicho: 57.36. Error: -7.36
# Real: 85.00 Predicho: 79.69. Error: 5.31
# Real: 100.00 Predicho: 98.37. Error: 1.63
# Real: 170.00 Predicho: 121.25. Error: 48.75
# Real: 50.00 Predicho: 69.13. Error: -19.13
# Real: 120.00 Predicho: 100.08. Error: 19.92
# Real: 65.00 Predicho: 68.20. Error: -3.20
# Real: 180.00 Predicho: 115.36. Error: 64.64
# Real: 40.00 Predicho: 80.18. Error: -40.18
# Real: 26.00 Predicho: 31.36. Error: -5.36
# Real: 27.00 Predicho: 28.46. Error: -1.46
# Real: 110.00 Predicho: 59.84. Error: 50.16
# Real: 36.00 Predicho: 25.43. Error: 10.57
# Real: 35.00 Predicho: 33.04. Error: 1.96
# Real: 44.00 Predicho: 65.32. Error: -21.32
# Real: 180.00 Predicho: 155.28. Error: 24.72
# Real: 40.00 Predicho: 47.75. Error: -7.75
# Real: 60.00 Predicho: 70.11. Error: -10.11
# Real: 113.00 Predicho: 67.76. Error: 45.24
# Real: 40.00 Predicho: 25.67. Error: 14.33
# Real: 49.00 Predicho: 54.56. Error: -5.56
# Real: 80.00 Predicho: 76.00. Error: 4.00
# Real: 46.00 Predicho: 63.39. Error: -17.39
# Real: 120.00 Predicho: 110.54. Error: 9.46
# Real: 79.00 Predicho: 79.48. Error: -0.48
# Real: 30.00 Predicho: 35.11. Error: -5.11
# Real: 30.00 Predicho: 46.41. Error: -16.41
# Real: 120.00 Predicho: 83.60. Error: 36.40
# Real: 75.00 Predicho: 72.70. Error: 2.30
# Real: 70.00 Predicho: 78.48. Error: -8.48
# Real: 20.00 Predicho: 26.36. Error: -6.36
# Real: 55.00 Predicho: 91.45. Error: -36.45
# Real: 59.00 Predicho: 72.36. Error: -13.36
# Real: 40.00 Predicho: 33.35. Error: 6.65
# Real: 30.00 Predicho: 30.40. Error: -0.40
# Real: 58.00 Predicho: 69.82. Error: -11.82
# Real: 19.00 Predicho: 27.49. Error: -8.49
# Real: 20.00 Predicho: 15.91. Error: 4.09
# Real: 35.00 Predicho: 32.53. Error: 2.47
# Real: 29.00 Predicho: 49.52. Error: -20.52
# Real: 32.00 Predicho: 31.91. Error: 0.09
# Real: 48.00 Predicho: 55.30. Error: -7.30
# Real: 40.00 Predicho: 36.52. Error: 3.48
# Real: 74.00 Predicho: 33.52. Error: 40.48
# Real: 31.00 Predicho: 38.18. Error: -7.18
# Real: 24.00 Predicho: 34.59. Error: -10.59
# Real: 190.00 Predicho: 132.64. Error: 57.36
# Real: 40.00 Predicho: 36.70. Error: 3.30
# Real: 85.00 Predicho: 73.00. Error: 12.00
# Real: 30.00 Predicho: 41.19. Error: -11.19
# Real: 50.00 Predicho: 56.41. Error: -6.41
# Real: 71.00 Predicho: 69.66. Error: 1.34
# Real: 30.00 Predicho: 35.34. Error: -5.34
# Real: 30.00 Predicho: 35.76. Error: -5.76
# Real: 18.00 Predicho: 36.36. Error: -18.36
# Real: 50.00 Predicho: 46.53. Error: 3.47
# Real: 60.00 Predicho: 65.95. Error: -5.95
# Real: 35.00 Predicho: 30.28. Error: 4.72
# Real: 89.00 Predicho: 113.15. Error: -24.15
# Real: 60.00 Predicho: 78.07. Error: -18.07
# Real: 77.00 Predicho: 59.90. Error: 17.10
# Real: 17.00 Predicho: 35.99. Error: -18.99
# Real: 50.00 Predicho: 64.81. Error: -14.81
# Real: 15.00 Predicho: 38.24. Error: -23.24
# Real: 60.00 Predicho: 55.79. Error: 4.21
# Real: 90.00 Predicho: 98.23. Error: -8.23
# Real: 55.00 Predicho: 72.09. Error: -17.09
# Real: 80.00 Predicho: 75.28. Error: 4.72
# Real: 50.00 Predicho: 29.08. Error: 20.92
# Real: 40.00 Predicho: 26.68. Error: 13.32
# Real: 32.00 Predicho: 41.83. Error: -9.83
# Real: 35.00 Predicho: 42.24. Error: -7.24
# Real: 69.00 Predicho: 93.33. Error: -24.33
# Real: 50.00 Predicho: 79.85. Error: -29.85
# Real: 23.00 Predicho: 39.80. Error: -16.80
# Real: 89.00 Predicho: 92.04. Error: -3.04
# Real: 20.00 Predicho: 17.45. Error: 2.55
# Real: 75.00 Predicho: 50.23. Error: 24.77
# Real: 60.00 Predicho: 54.86. Error: 5.14
# Real: 150.00 Predicho: 120.22. Error: 29.78
# Real: 100.00 Predicho: 85.47. Error: 14.53
# Real: 60.00 Predicho: 65.84. Error: -5.84
# Real: 50.00 Predicho: 58.95. Error: -8.95
# Real: 72.00 Predicho: 56.09. Error: 15.91
# Real: 25.00 Predicho: 39.83. Error: -14.83
# Real: 90.00 Predicho: 112.66. Error: -22.66
# Real: 70.00 Predicho: 58.55. Error: 11.45
# Real: 80.00 Predicho: 81.74. Error: -1.74
# Real: 28.00 Predicho: 21.25. Error: 6.75
# Real: 170.00 Predicho: 144.26. Error: 25.74
# Real: 34.00 Predicho: 32.61. Error: 1.39
# Real: 90.00 Predicho: 71.37. Error: 18.63
# Real: 35.00 Predicho: 32.33. Error: 2.67
# Real: 30.00 Predicho: 23.62. Error: 6.38
# Real: 15.00 Predicho: 20.75. Error: -5.75
# Real: 126.00 Predicho: 130.87. Error: -4.87
# Real: 40.00 Predicho: 42.95. Error: -2.95
# Real: 38.00 Predicho: 31.51. Error: 6.49
# Real: 25.00 Predicho: 46.72. Error: -21.72
# Real: 32.00 Predicho: 33.61. Error: -1.61
# Real: 55.00 Predicho: 57.84. Error: -2.84
# Real: 40.00 Predicho: 29.53. Error: 10.47
# Real: 30.00 Predicho: 34.06. Error: -4.06
# Real: 25.00 Predicho: 30.21. Error: -5.21
# Real: 110.00 Predicho: 88.86. Error: 21.14
# Real: 46.00 Predicho: 82.83. Error: -36.83
# Real: 68.00 Predicho: 63.43. Error: 4.57
# Real: 160.00 Predicho: 158.99. Error: 1.01
# Real: 60.00 Predicho: 58.06. Error: 1.94
# Real: 49.00 Predicho: 56.64. Error: -7.64
# Real: 140.00 Predicho: 155.18. Error: -15.18
# Real: 20.00 Predicho: 36.30. Error: -16.30
# Real: 36.00 Predicho: 35.49. Error: 0.51
# Real: 18.00 Predicho: 18.53. Error: -0.53
# Real: 50.00 Predicho: 80.37. Error: -30.37
# Real: 23.00 Predicho: 30.10. Error: -7.10
# Real: 35.00 Predicho: 54.77. Error: -19.77
# Real: 68.00 Predicho: 77.88. Error: -9.88
# Real: 49.00 Predicho: 51.25. Error: -2.25
# Real: 40.00 Predicho: 50.93. Error: -10.93
# Real: 20.00 Predicho: 45.47. Error: -25.47
# Real: 19.00 Predicho: 18.48. Error: 0.52
# Real: 120.00 Predicho: 69.65. Error: 50.35
# Real: 40.00 Predicho: 26.06. Error: 13.94
# Real: 60.00 Predicho: 60.01. Error: -0.01
# Real: 95.00 Predicho: 68.26. Error: 26.74
# Real: 144.00 Predicho: 134.31. Error: 9.69
# Real: 100.00 Predicho: 77.49. Error: 22.51
# Real: 60.00 Predicho: 42.90. Error: 17.10
# Real: 100.00 Predicho: 134.36. Error: -34.36
# Real: 20.00 Predicho: 19.90. Error: 0.10
# Real: 50.00 Predicho: 52.57. Error: -2.57
# Real: 71.00 Predicho: 125.90. Error: -54.90
# Real: 48.00 Predicho: 52.63. Error: -4.63
# Real: 22.00 Predicho: 40.05. Error: -18.05
# Real: 49.00 Predicho: 54.81. Error: -5.81
# Real: 70.00 Predicho: 64.14. Error: 5.86
# Real: 30.00 Predicho: 52.29. Error: -22.29
# Real: 50.00 Predicho: 50.58. Error: -0.58
# Real: 75.00 Predicho: 73.11. Error: 1.89
# Real: 25.00 Predicho: 25.72. Error: -0.72
# Real: 107.00 Predicho: 111.69. Error: -4.69
# Real: 20.00 Predicho: 29.38. Error: -9.38
# Real: 45.00 Predicho: 39.50. Error: 5.50
# Real: 29.00 Predicho: 33.56. Error: -4.56
# Real: 100.00 Predicho: 79.09. Error: 20.91
# Real: 65.00 Predicho: 68.66. Error: -3.66
# Real: 50.00 Predicho: 80.65. Error: -30.65
# Real: 58.00 Predicho: 57.92. Error: 0.08
# Real: 24.00 Predicho: 30.02. Error: -6.02
# Real: 60.00 Predicho: 75.11. Error: -15.11
# Real: 85.00 Predicho: 87.84. Error: -2.84
# Real: 130.00 Predicho: 122.22. Error: 7.78
# Real: 60.00 Predicho: 68.09. Error: -8.09
# Real: 50.00 Predicho: 51.19. Error: -1.19
# Real: 45.00 Predicho: 61.98. Error: -16.98
# Real: 79.00 Predicho: 68.52. Error: 10.48
# Real: 49.00 Predicho: 69.21. Error: -20.21
# Real: 60.00 Predicho: 71.64. Error: -11.64
# Real: 165.00 Predicho: 160.12. Error: 4.88
# Real: 50.00 Predicho: 66.04. Error: -16.04
# Real: 160.00 Predicho: 141.28. Error: 18.72
# Real: 42.00 Predicho: 65.43. Error: -23.43
# Real: 33.00 Predicho: 36.82. Error: -3.82
# Real: 80.00 Predicho: 79.34. Error: 0.66
# Real: 60.00 Predicho: 72.36. Error: -12.36
# Real: 35.00 Predicho: 35.86. Error: -0.86
# Real: 15.00 Predicho: 28.85. Error: -13.85
# Real: 150.00 Predicho: 110.02. Error: 39.98
# Real: 29.00 Predicho: 34.33. Error: -5.33
# Real: 38.00 Predicho: 45.11. Error: -7.11
# Real: 150.00 Predicho: 121.20. Error: 28.80
# Real: 140.00 Predicho: 154.29. Error: -14.29
# Real: 195.00 Predicho: 135.18. Error: 59.82
# Real: 23.00 Predicho: 24.28. Error: -1.28
# Real: 25.00 Predicho: 28.68. Error: -3.68
# Real: 37.00 Predicho: 30.81. Error: 6.19
# Real: 50.00 Predicho: 27.61. Error: 22.39
# Real: 30.00 Predicho: 32.32. Error: -2.32
# Real: 75.00 Predicho: 75.13. Error: -0.13
# Real: 18.00 Predicho: 27.49. Error: -9.49
# Real: 31.00 Predicho: 33.26. Error: -2.26
# Real: 45.00 Predicho: 52.12. Error: -7.12
# Real: 120.00 Predicho: 108.14. Error: 11.86
# Real: 32.00 Predicho: 31.35. Error: 0.65
# Real: 71.00 Predicho: 88.64. Error: -17.64
# Real: 25.00 Predicho: 37.40. Error: -12.40
# Real: 150.00 Predicho: 125.87. Error: 24.13
# Real: 30.00 Predicho: 48.34. Error: -18.34
# Real: 80.00 Predicho: 56.05. Error: 23.95
# Real: 23.00 Predicho: 38.50. Error: -15.50
# Real: 40.00 Predicho: 69.50. Error: -29.50
# Real: 45.00 Predicho: 31.64. Error: 13.36
# Real: 72.00 Predicho: 64.67. Error: 7.33
# Real: 120.00 Predicho: 116.79. Error: 3.21
# Real: 45.00 Predicho: 36.48. Error: 8.52
# Real: 59.00 Predicho: 62.23. Error: -3.23
# Real: 88.00 Predicho: 82.65. Error: 5.35
# Real: 36.00 Predicho: 36.68. Error: -0.68
# Real: 90.00 Predicho: 74.40. Error: 15.60
# Real: 70.00 Predicho: 62.22. Error: 7.78
# Real: 67.00 Predicho: 82.51. Error: -15.51
# Real: 95.00 Predicho: 69.08. Error: 25.92
# Real: 110.00 Predicho: 118.02. Error: -8.02
# Real: 96.00 Predicho: 90.18. Error: 5.82
# Real: 17.00 Predicho: 24.73. Error: -7.73
# Real: 50.00 Predicho: 55.34. Error: -5.34
# Real: 35.00 Predicho: 32.92. Error: 2.08
# Real: 26.00 Predicho: 29.57. Error: -3.57
# Real: 70.00 Predicho: 66.83. Error: 3.17
# Real: 42.00 Predicho: 36.62. Error: 5.38
# Real: 32.00 Predicho: 20.76. Error: 11.24
# Real: 60.00 Predicho: 73.93. Error: -13.93
# Real: 105.00 Predicho: 99.91. Error: 5.09
# Real: 21.00 Predicho: 22.28. Error: -1.28
# Real: 26.00 Predicho: 20.04. Error: 5.96
# Real: 59.00 Predicho: 68.53. Error: -9.53
# Real: 19.00 Predicho: 22.20. Error: -3.20
# Real: 50.00 Predicho: 38.12. Error: 11.88
# Real: 45.00 Predicho: 57.31. Error: -12.31
# Real: 75.00 Predicho: 85.45. Error: -10.45
# Real: 15.00 Predicho: 20.26. Error: -5.26
# Real: 30.00 Predicho: 47.17. Error: -17.17
# Real: 25.00 Predicho: 35.14. Error: -10.14
# Real: 99.00 Predicho: 80.30. Error: 18.70
# Real: 47.00 Predicho: 35.01. Error: 11.99
# Real: 25.00 Predicho: 22.64. Error: 2.36
# Real: 77.00 Predicho: 43.71. Error: 33.29
# Real: 95.00 Predicho: 95.85. Error: -0.85
# Real: 52.00 Predicho: 76.62. Error: -24.62
# Real: 25.00 Predicho: 26.53. Error: -1.53
# Real: 100.00 Predicho: 107.93. Error: -7.93
# Real: 45.00 Predicho: 78.15. Error: -33.15
# Real: 65.00 Predicho: 66.19. Error: -1.19
# Real: 25.00 Predicho: 27.16. Error: -2.16
# Real: 60.00 Predicho: 51.94. Error: 8.06
# Real: 38.00 Predicho: 57.32. Error: -19.32
# Real: 49.00 Predicho: 57.87. Error: -8.87
# Real: 74.00 Predicho: 76.53. Error: -2.53
# Real: 50.00 Predicho: 59.77. Error: -9.77
# Real: 35.00 Predicho: 63.93. Error: -28.93
# Real: 20.00 Predicho: 32.23. Error: -12.23
# Real: 42.00 Predicho: 39.13. Error: 2.87
# Real: 115.00 Predicho: 81.58. Error: 33.42
# Real: 35.00 Predicho: 38.02. Error: -3.02
# Real: 75.00 Predicho: 80.24. Error: -5.24
# Real: 84.00 Predicho: 89.00. Error: -5.00
# Real: 70.00 Predicho: 36.58. Error: 33.42
# Real: 78.00 Predicho: 27.47. Error: 50.53
# Real: 65.00 Predicho: 57.56. Error: 7.44
# Real: 90.00 Predicho: 72.10. Error: 17.90
# Real: 27.00 Predicho: 24.10. Error: 2.90
# Real: 35.00 Predicho: 53.33. Error: -18.33
# Real: 60.00 Predicho: 79.21. Error: -19.21
# Real: 70.00 Predicho: 97.30. Error: -27.30
# Real: 59.00 Predicho: 49.83. Error: 9.17
# Real: 30.00 Predicho: 27.24. Error: 2.76
# Real: 70.00 Predicho: 45.53. Error: 24.47
# Real: 89.00 Predicho: 105.99. Error: -16.99
# Real: 24.00 Predicho: 32.78. Error: -8.78
# Real: 36.00 Predicho: 37.42. Error: -1.42
# Real: 80.00 Predicho: 88.73. Error: -8.73
# Real: 27.00 Predicho: 30.72. Error: -3.72
# Real: 95.00 Predicho: 95.81. Error: -0.81
# Real: 140.00 Predicho: 123.63. Error: 16.37
# Real: 19.00 Predicho: 31.21. Error: -12.21
# Real: 60.00 Predicho: 74.34. Error: -14.34
# Real: 70.00 Predicho: 56.84. Error: 13.16
# Real: 100.00 Predicho: 86.76. Error: 13.24
# Real: 21.00 Predicho: 27.52. Error: -6.52
# Real: 25.00 Predicho: 30.80. Error: -5.80
# Real: 70.00 Predicho: 67.65. Error: 2.35
# Real: 110.00 Predicho: 86.91. Error: 23.09
# Real: 55.00 Predicho: 50.33. Error: 4.67
# Real: 170.00 Predicho: 148.07. Error: 21.93
# Real: 60.00 Predicho: 85.51. Error: -25.51
# Real: 120.00 Predicho: 83.26. Error: 36.74
# Real: 85.00 Predicho: 36.23. Error: 48.77
# Real: 30.00 Predicho: 30.05. Error: -0.05
# Real: 75.00 Predicho: 67.57. Error: 7.43
# Real: 28.00 Predicho: 32.98. Error: -4.98
# Real: 52.00 Predicho: 43.99. Error: 8.01
# Real: 24.00 Predicho: 20.78. Error: 3.22
# Real: 95.00 Predicho: 60.01. Error: 34.99
# Real: 25.00 Predicho: 28.85. Error: -3.85
# Real: 35.00 Predicho: 33.79. Error: 1.21
# Real: 60.00 Predicho: 85.92. Error: -25.92
# Real: 68.00 Predicho: 62.52. Error: 5.48
# Real: 20.00 Predicho: 19.10. Error: 0.90
# Real: 62.00 Predicho: 68.46. Error: -6.46
# Real: 34.00 Predicho: 27.70. Error: 6.30
# Real: 55.00 Predicho: 55.12. Error: -0.12
# Real: 50.00 Predicho: 55.52. Error: -5.52
# Real: 34.00 Predicho: 55.83. Error: -21.83
# Real: 110.00 Predicho: 96.47. Error: 13.53
# Real: 43.00 Predicho: 50.50. Error: -7.50
# Real: 60.00 Predicho: 67.29. Error: -7.29
# Real: 60.00 Predicho: 67.18. Error: -7.18
# Real: 70.00 Predicho: 78.39. Error: -8.39
# Real: 150.00 Predicho: 38.13. Error: 111.87
# Real: 37.00 Predicho: 53.46. Error: -16.46
# Real: 42.00 Predicho: 53.41. Error: -11.41
# Real: 28.00 Predicho: 34.93. Error: -6.93
# Real: 25.00 Predicho: 27.34. Error: -2.34
# Real: 25.00 Predicho: 40.28. Error: -15.28
# Real: 39.00 Predicho: 81.33. Error: -42.33
# Real: 60.00 Predicho: 47.56. Error: 12.44
# Real: 65.00 Predicho: 58.26. Error: 6.74
# Real: 20.00 Predicho: 22.29. Error: -2.29
# Real: 80.00 Predicho: 79.28. Error: 0.72
# Real: 12.00 Predicho: 40.83. Error: -28.83
# Real: 59.00 Predicho: 61.35. Error: -2.35
# Real: 60.00 Predicho: 69.45. Error: -9.45
# Real: 20.00 Predicho: 24.71. Error: -4.71
# Real: 25.00 Predicho: 31.86. Error: -6.86
# Real: 110.00 Predicho: 91.73. Error: 18.27
# Real: 15.00 Predicho: 18.33. Error: -3.33
# Real: 27.00 Predicho: 28.75. Error: -1.75
# Real: 100.00 Predicho: 44.74. Error: 55.26
# Real: 120.00 Predicho: 85.04. Error: 34.96
# Real: 100.00 Predicho: 126.19. Error: -26.19
# Real: 80.00 Predicho: 88.94. Error: -8.94
# Real: 117.00 Predicho: 111.15. Error: 5.85
# Real: 44.00 Predicho: 63.00. Error: -19.00
# Real: 50.00 Predicho: 53.15. Error: -3.15
# Real: 20.00 Predicho: 31.37. Error: -11.37
# Real: 70.00 Predicho: 87.03. Error: -17.03
# Real: 17.00 Predicho: 26.27. Error: -9.27
# Real: 19.00 Predicho: 18.57. Error: 0.43
# Real: 60.00 Predicho: 63.81. Error: -3.81
# Real: 30.00 Predicho: 29.66. Error: 0.34
# Real: 70.00 Predicho: 76.86. Error: -6.86
# Real: 20.00 Predicho: 23.36. Error: -3.36
# Real: 18.00 Predicho: 18.61. Error: -0.61
# Real: 15.00 Predicho: 35.50. Error: -20.50
# Real: 55.00 Predicho: 72.16. Error: -17.16
# Real: 25.00 Predicho: 24.56. Error: 0.44
# Real: 25.00 Predicho: 29.41. Error: -4.41
# Real: 160.00 Predicho: 141.84. Error: 18.16
# Real: 18.00 Predicho: 22.77. Error: -4.77
# Real: 39.00 Predicho: 37.88. Error: 1.12
# Real: 90.00 Predicho: 97.03. Error: -7.03
# Real: 135.00 Predicho: 75.38. Error: 59.62
# Real: 79.00 Predicho: 72.18. Error: 6.82
# Real: 85.00 Predicho: 67.94. Error: 17.06
# Real: 27.00 Predicho: 30.16. Error: -3.16
# Real: 25.00 Predicho: 29.28. Error: -4.28
# Real: 60.00 Predicho: 71.29. Error: -11.29
# Real: 140.00 Predicho: 123.03. Error: 16.97
# Real: 27.00 Predicho: 28.70. Error: -1.70
# Real: 135.00 Predicho: 89.06. Error: 45.94
# Real: 35.00 Predicho: 26.88. Error: 8.12
# Real: 150.00 Predicho: 127.18. Error: 22.82
# Real: 60.00 Predicho: 72.08. Error: -12.08
# Real: 19.00 Predicho: 28.85. Error: -9.85
# Real: 70.00 Predicho: 74.90. Error: -4.90
# Real: 199.00 Predicho: 84.64. Error: 114.36
# Real: 42.00 Predicho: 57.54. Error: -15.54
# Real: 29.00 Predicho: 37.40. Error: -8.40
# Real: 79.00 Predicho: 103.72. Error: -24.72
# Real: 50.00 Predicho: 23.96. Error: 26.04
# Real: 70.00 Predicho: 76.03. Error: -6.03
# Real: 110.00 Predicho: 110.69. Error: -0.69
# Real: 37.00 Predicho: 29.60. Error: 7.40
# Real: 33.00 Predicho: 26.94. Error: 6.06
# Real: 45.00 Predicho: 40.62. Error: 4.38
# Real: 45.00 Predicho: 36.35. Error: 8.65
# Real: 20.00 Predicho: 29.82. Error: -9.82
# Real: 149.00 Predicho: 126.09. Error: 22.91
# Real: 30.00 Predicho: 26.68. Error: 3.32
# Real: 38.00 Predicho: 68.48. Error: -30.48
# Real: 19.00 Predicho: 35.14. Error: -16.14
# Real: 35.00 Predicho: 38.45. Error: -3.45
# Real: 39.00 Predicho: 60.28. Error: -21.28
# Real: 15.00 Predicho: 22.07. Error: -7.07
# Real: 10.00 Predicho: 19.50. Error: -9.50
# Real: 26.00 Predicho: 36.58. Error: -10.58
# Real: 85.00 Predicho: 76.67. Error: 8.33
# Real: 100.00 Predicho: 103.64. Error: -3.64
# Real: 50.00 Predicho: 52.44. Error: -2.44
# Real: 70.00 Predicho: 62.69. Error: 7.31
# Real: 80.00 Predicho: 71.71. Error: 8.29
# Real: 45.00 Predicho: 101.73. Error: -56.73
# Real: 50.00 Predicho: 54.79. Error: -4.79
# Real: 29.00 Predicho: 30.68. Error: -1.68
# Real: 143.00 Predicho: 83.79. Error: 59.21
# Real: 22.00 Predicho: 32.32. Error: -10.32
# Real: 65.00 Predicho: 71.48. Error: -6.48
# Real: 50.00 Predicho: 39.52. Error: 10.48
# Real: 60.00 Predicho: 63.13. Error: -3.13
# Real: 30.00 Predicho: 28.08. Error: 1.92
# Real: 65.00 Predicho: 67.61. Error: -2.61
# Real: 45.00 Predicho: 35.28. Error: 9.72
# Real: 25.00 Predicho: 35.62. Error: -10.62
# Real: 50.00 Predicho: 53.02. Error: -3.02
# Real: 120.00 Predicho: 141.66. Error: -21.66
# Real: 45.00 Predicho: 60.86. Error: -15.86
# Real: 50.00 Predicho: 35.96. Error: 14.04
# Real: 60.00 Predicho: 83.62. Error: -23.62
# Real: 50.00 Predicho: 51.67. Error: -1.67
# Real: 70.00 Predicho: 68.07. Error: 1.93
# Real: 85.00 Predicho: 92.21. Error: -7.21
# Real: 60.00 Predicho: 61.05. Error: -1.05
# Real: 40.00 Predicho: 30.75. Error: 9.25
# Real: 30.00 Predicho: 32.71. Error: -2.71
# Real: 25.00 Predicho: 25.36. Error: -0.36
# Real: 70.00 Predicho: 83.22. Error: -13.22
# Real: 25.00 Predicho: 22.43. Error: 2.57
# Real: 20.00 Predicho: 29.15. Error: -9.15
# Real: 55.00 Predicho: 71.96. Error: -16.96
# Real: 14.00 Predicho: 18.74. Error: -4.74
# Real: 50.00 Predicho: 60.28. Error: -10.28
# Real: 45.00 Predicho: 29.62. Error: 15.38
# Real: 18.00 Predicho: 22.50. Error: -4.50
# Real: 72.00 Predicho: 56.33. Error: 15.67
# Real: 26.00 Predicho: 27.05. Error: -1.05
# Real: 20.00 Predicho: 31.64. Error: -11.64
# Real: 30.00 Predicho: 42.74. Error: -12.74
# Real: 55.00 Predicho: 55.17. Error: -0.17
# Real: 35.00 Predicho: 33.27. Error: 1.73
# Real: 78.00 Predicho: 101.82. Error: -23.82
# Real: 16.00 Predicho: 45.15. Error: -29.15
# Real: 95.00 Predicho: 111.71. Error: -16.71
# Real: 28.00 Predicho: 29.56. Error: -1.56
# Real: 25.00 Predicho: 32.16. Error: -7.16
# Real: 156.00 Predicho: 102.49. Error: 53.51
# Real: 40.00 Predicho: 66.49. Error: -26.49
# Real: 58.00 Predicho: 66.68. Error: -8.68
# Real: 13.00 Predicho: 23.89. Error: -10.89
# Real: 70.00 Predicho: 46.65. Error: 23.35
# Real: 40.00 Predicho: 37.30. Error: 2.70
# Real: 70.00 Predicho: 56.16. Error: 13.84
# Real: 60.00 Predicho: 69.88. Error: -9.88
# Real: 20.00 Predicho: 19.29. Error: 0.71
# Real: 30.00 Predicho: 37.81. Error: -7.81
# Real: 37.00 Predicho: 46.67. Error: -9.67
# Real: 29.00 Predicho: 41.33. Error: -12.33
# Real: 190.00 Predicho: 139.13. Error: 50.87
# Real: 19.00 Predicho: 23.98. Error: -4.98
# Real: 50.00 Predicho: 36.70. Error: 13.30
# Real: 23.00 Predicho: 43.68. Error: -20.68
# Real: 44.00 Predicho: 46.85. Error: -2.85
# Real: 42.00 Predicho: 49.01. Error: -7.01
# Real: 99.00 Predicho: 80.96. Error: 18.04
# Real: 99.00 Predicho: 71.97. Error: 27.03
# Real: 45.00 Predicho: 54.53. Error: -9.53
# Real: 105.00 Predicho: 70.05. Error: 34.95
# Real: 110.00 Predicho: 114.18. Error: -4.18
# Real: 39.00 Predicho: 35.63. Error: 3.37
# Real: 44.00 Predicho: 48.19. Error: -4.19
# Real: 100.00 Predicho: 101.63. Error: -1.63
# Real: 30.00 Predicho: 25.38. Error: 4.62
# Real: 25.00 Predicho: 40.35. Error: -15.35
# Real: 20.00 Predicho: 21.83. Error: -1.83
# Real: 30.00 Predicho: 71.12. Error: -41.12
# Real: 17.00 Predicho: 23.45. Error: -6.45
# Real: 50.00 Predicho: 102.17. Error: -52.17
# Real: 18.00 Predicho: 21.28. Error: -3.28
# Real: 63.00 Predicho: 59.89. Error: 3.11
# Real: 50.00 Predicho: 33.58. Error: 16.42
# Real: 75.00 Predicho: 90.09. Error: -15.09
# Real: 120.00 Predicho: 91.05. Error: 28.95
# Real: 30.00 Predicho: 61.15. Error: -31.15
# Real: 60.00 Predicho: 75.09. Error: -15.09
# Real: 85.00 Predicho: 71.61. Error: 13.39
# Real: 35.00 Predicho: 26.35. Error: 8.65
# Real: 85.00 Predicho: 75.47. Error: 9.53
# Real: 90.00 Predicho: 98.11. Error: -8.11
# Real: 22.00 Predicho: 25.20. Error: -3.20
# Real: 15.00 Predicho: 36.38. Error: -21.38
# Real: 25.00 Predicho: 29.08. Error: -4.08
# Real: 30.00 Predicho: 21.77. Error: 8.23
# Real: 18.00 Predicho: 34.21. Error: -16.21
# Real: 50.00 Predicho: 55.85. Error: -5.85
# Real: 16.00 Predicho: 27.87. Error: -11.87
# Real: 25.00 Predicho: 35.37. Error: -10.37
# Real: 75.00 Predicho: 59.62. Error: 15.38
# Real: 35.00 Predicho: 68.73. Error: -33.73
# Real: 55.00 Predicho: 88.21. Error: -33.21
# Real: 23.00 Predicho: 25.75. Error: -2.75
# Real: 30.00 Predicho: 37.89. Error: -7.89
# Real: 48.00 Predicho: 74.56. Error: -26.56
# Real: 77.00 Predicho: 79.80. Error: -2.80
# Real: 68.00 Predicho: 60.05. Error: 7.95
# Real: 69.00 Predicho: 56.18. Error: 12.82
# Real: 75.00 Predicho: 70.18. Error: 4.82
# Real: 130.00 Predicho: 143.72. Error: -13.72
# ...
# Real: 45.00 Predicho: 61.47. Error: -16.47
# Real: 74.00 Predicho: 39.00. Error: 35.00
# Real: 130.00 Predicho: 125.41. Error: 4.59
# Real: 39.00 Predicho: 39.96. Error: -0.96
# Real: 103.00 Predicho: 76.21. Error: 26.79
# Real: 119.00 Predicho: 103.38. Error: 15.62
# Real: 19.00 Predicho: 21.52. Error: -2.52
# Real: 60.00 Predicho: 86.83. Error: -26.83
# Real: 37.00 Predicho: 39.57. Error: -2.57
# Real: 35.00 Predicho: 41.38. Error: -6.38
# Real: 29.00 Predicho: 26.27. Error: 2.73
# Real: 26.00 Predicho: 29.37. Error: -3.37
# Real: 30.00 Predicho: 28.33. Error: 1.67
# Real: 18.00 Predicho: 32.44. Error: -14.44
# Real: 40.00 Predicho: 41.39. Error: -1.39
# Real: 85.00 Predicho: 66.66. Error: 18.34
# Real: 20.00 Predicho: 33.21. Error: -13.21
# Real: 25.00 Predicho: 47.69. Error: -22.69
# Real: 85.00 Predicho: 53.57. Error: 31.43
# Real: 55.00 Predicho: 72.41. Error: -17.41
# Real: 50.00 Predicho: 56.89. Error: -6.89
# Real: 149.00 Predicho: 81.31. Error: 67.69
# Real: 125.00 Predicho: 91.14. Error: 33.86
# Real: 40.00 Predicho: 74.11. Error: -34.11
# Real: 95.00 Predicho: 68.50. Error: 26.50
# Real: 120.00 Predicho: 81.51. Error: 38.49
# Real: 18.00 Predicho: 40.37. Error: -22.37
# Real: 26.00 Predicho: 34.51. Error: -8.51
# Real: 45.00 Predicho: 45.08. Error: -0.08
# Real: 68.00 Predicho: 82.76. Error: -14.76
# Real: 35.00 Predicho: 69.68. Error: -34.68
# Real: 20.00 Predicho: 73.81. Error: -53.81
# Real: 85.00 Predicho: 61.52. Error: 23.48
# Real: 45.00 Predicho: 65.29. Error: -20.29
# Real: 40.00 Predicho: 38.81. Error: 1.19
# Real: 62.00 Predicho: 76.92. Error: -14.92
# Real: 60.00 Predicho: 57.72. Error: 2.28
# Real: 35.00 Predicho: 39.30. Error: -4.30
# Real: 45.00 Predicho: 41.60. Error: 3.40
# Real: 30.00 Predicho: 29.66. Error: 0.34
# Real: 80.00 Predicho: 79.85. Error: 0.15
# Real: 135.00 Predicho: 131.61. Error: 3.39
# Real: 119.00 Predicho: 145.55. Error: -26.55
# Real: 60.00 Predicho: 62.45. Error: -2.45
# Real: 78.00 Predicho: 43.09. Error: 34.91
# Real: 55.00 Predicho: 71.86. Error: -16.86
# Real: 90.00 Predicho: 89.11. Error: 0.89
# Real: 100.00 Predicho: 103.20. Error: -3.20
# Real: 60.00 Predicho: 78.28. Error: -18.28
# Real: 60.00 Predicho: 83.50. Error: -23.50
# Real: 55.00 Predicho: 87.07. Error: -32.07
# Real: 30.00 Predicho: 26.35. Error: 3.65
# Real: 55.00 Predicho: 70.55. Error: -15.55
# Real: 30.00 Predicho: 29.05. Error: 0.95
# Real: 66.00 Predicho: 51.01. Error: 14.99
# Real: 19.00 Predicho: 24.91. Error: -5.91
# Real: 45.00 Predicho: 62.20. Error: -17.20
# Real: 115.00 Predicho: 111.79. Error: 3.21
# Real: 30.00 Predicho: 35.58. Error: -5.58
# Real: 89.00 Predicho: 76.66. Error: 12.34
# Real: 65.00 Predicho: 73.19. Error: -8.19
# Real: 80.00 Predicho: 75.64. Error: 4.36
# Real: 18.00 Predicho: 21.23. Error: -3.23
# Real: 45.00 Predicho: 59.90. Error: -14.90
# Real: 59.00 Predicho: 67.29. Error: -8.29
# Real: 48.00 Predicho: 71.00. Error: -23.00
# Real: 13.00 Predicho: 19.64. Error: -6.64
# Real: 20.00 Predicho: 33.47. Error: -13.47
# Real: 35.00 Predicho: 37.91. Error: -2.91
# Real: 49.00 Predicho: 60.07. Error: -11.07
# Real: 21.00 Predicho: 22.16. Error: -1.16
# Real: 31.00 Predicho: 26.81. Error: 4.19
# Real: 100.00 Predicho: 79.48. Error: 20.52
# Real: 87.00 Predicho: 63.18. Error: 23.82
# Real: 89.00 Predicho: 89.87. Error: -0.87
# Real: 90.00 Predicho: 61.76. Error: 28.24
# Real: 60.00 Predicho: 61.63. Error: -1.63
# Real: 125.00 Predicho: 122.36. Error: 2.64
# Real: 25.00 Predicho: 21.46. Error: 3.54
# Real: 40.00 Predicho: 51.50. Error: -11.50
# Real: 79.00 Predicho: 38.75. Error: 40.25
# Real: 22.00 Predicho: 20.03. Error: 1.97
# Real: 60.00 Predicho: 58.96. Error: 1.04
# Real: 20.00 Predicho: 18.25. Error: 1.75
# Real: 68.00 Predicho: 80.26. Error: -12.26
# Real: 30.00 Predicho: 30.14. Error: -0.14
# Real: 15.00 Predicho: 20.99. Error: -5.99
# Real: 140.00 Predicho: 106.74. Error: 33.26
# Real: 50.00 Predicho: 59.66. Error: -9.66
# Real: 50.00 Predicho: 53.37. Error: -3.37
# Real: 80.00 Predicho: 90.86. Error: -10.86
# Real: 66.00 Predicho: 49.31. Error: 16.69
# Real: 70.00 Predicho: 47.98. Error: 22.02
# Real: 40.00 Predicho: 36.88. Error: 3.12
# Real: 65.00 Predicho: 28.88. Error: 36.12
# Real: 28.00 Predicho: 34.22. Error: -6.22
# Real: 58.00 Predicho: 62.57. Error: -4.57
# Real: 20.00 Predicho: 34.62. Error: -14.62
# Real: 25.00 Predicho: 22.99. Error: 2.01
# Real: 115.00 Predicho: 115.53. Error: -0.53
# Real: 25.00 Predicho: 28.20. Error: -3.20
# Real: 30.00 Predicho: 33.72. Error: -3.72
# Real: 50.00 Predicho: 55.78. Error: -5.78
# Real: 150.00 Predicho: 124.52. Error: 25.48
# Real: 60.00 Predicho: 72.45. Error: -12.45
# Real: 35.00 Predicho: 67.10. Error: -32.10
# Real: 17.00 Predicho: 25.30. Error: -8.30
# Real: 10.00 Predicho: 70.46. Error: -60.46
# Real: 129.00 Predicho: 135.00. Error: -6.00
# Real: 23.00 Predicho: 121.52. Error: -98.52
# Real: 30.00 Predicho: 28.78. Error: 1.22
# Real: 20.00 Predicho: 31.68. Error: -11.68
# Real: 150.00 Predicho: 162.05. Error: -12.05
# Real: 35.00 Predicho: 70.52. Error: -35.52
# Real: 65.00 Predicho: 62.19. Error: 2.81
# Real: 24.00 Predicho: 31.62. Error: -7.62
# Real: 70.00 Predicho: 97.13. Error: -27.13
# Real: 20.00 Predicho: 25.14. Error: -5.14
# Real: 65.00 Predicho: 84.67. Error: -19.67
# Real: 40.00 Predicho: 27.41. Error: 12.59
# Real: 69.00 Predicho: 63.92. Error: 5.08
# Real: 60.00 Predicho: 36.51. Error: 23.49
# Real: 43.00 Predicho: 35.24. Error: 7.76
# Real: 39.00 Predicho: 37.52. Error: 1.48
# Real: 35.00 Predicho: 47.46. Error: -12.46
# Real: 90.00 Predicho: 51.65. Error: 38.35
# Real: 37.00 Predicho: 31.05. Error: 5.95
# Real: 60.00 Predicho: 39.52. Error: 20.48
# Real: 70.00 Predicho: 69.05. Error: 0.95
# Real: 97.00 Predicho: 81.78. Error: 15.22
# Real: 120.00 Predicho: 129.83. Error: -9.83
# Real: 30.00 Predicho: 38.01. Error: -8.01
# Real: 75.00 Predicho: 84.08. Error: -9.08
# Real: 55.00 Predicho: 61.80. Error: -6.80
# Real: 10.00 Predicho: 19.14. Error: -9.14
# Real: 65.00 Predicho: 53.48. Error: 11.52
# Real: 150.00 Predicho: 148.46. Error: 1.54
# Real: 132.00 Predicho: 106.19. Error: 25.81
# Real: 50.00 Predicho: 73.04. Error: -23.04
# Real: 49.00 Predicho: 70.07. Error: -21.07
# Real: 95.00 Predicho: 100.04. Error: -5.04
# Real: 180.00 Predicho: 127.00. Error: 53.00
# Real: 49.00 Predicho: 52.79. Error: -3.79
# Real: 25.00 Predicho: 30.13. Error: -5.13
# Real: 30.00 Predicho: 32.29. Error: -2.29
# Real: 65.00 Predicho: 78.01. Error: -13.01
# Real: 130.00 Predicho: 83.49. Error: 46.51
# Real: 55.00 Predicho: 64.65. Error: -9.65
# Real: 80.00 Predicho: 102.34. Error: -22.34
# Real: 35.00 Predicho: 35.16. Error: -0.16
# Real: 40.00 Predicho: 54.15. Error: -14.15
# Real: 65.00 Predicho: 82.82. Error: -17.82
# Real: 40.00 Predicho: 25.14. Error: 14.86
# Real: 30.00 Predicho: 29.56. Error: 0.44
# Real: 50.00 Predicho: 39.98. Error: 10.02
# Real: 80.00 Predicho: 77.70. Error: 2.30
# Real: 56.00 Predicho: 58.61. Error: -2.61
# Real: 77.00 Predicho: 46.79. Error: 30.21
# Real: 90.00 Predicho: 80.37. Error: 9.63
# Real: 180.00 Predicho: 146.64. Error: 33.36
# Real: 150.00 Predicho: 109.22. Error: 40.78
# Real: 140.00 Predicho: 150.85. Error: -10.85
# Real: 65.00 Predicho: 70.50. Error: -5.50
# Real: 35.00 Predicho: 68.48. Error: -33.48
# Real: 58.00 Predicho: 34.79. Error: 23.21
# Real: 60.00 Predicho: 106.55. Error: -46.55
# Real: 16.00 Predicho: 24.19. Error: -8.19
# Real: 55.00 Predicho: 61.85. Error: -6.85
# Real: 29.00 Predicho: 32.65. Error: -3.65
# Real: 55.00 Predicho: 71.46. Error: -16.46
# Real: 49.00 Predicho: 65.31. Error: -16.31
# Real: 67.00 Predicho: 73.02. Error: -6.02
# Real: 45.00 Predicho: 37.13. Error: 7.87
# Real: 45.00 Predicho: 28.60. Error: 16.40
# Real: 38.00 Predicho: 40.11. Error: -2.11
# Real: 130.00 Predicho: 78.28. Error: 51.72
# Real: 50.00 Predicho: 68.13. Error: -18.13
# Real: 97.00 Predicho: 64.85. Error: 32.15
# Real: 90.00 Predicho: 81.94. Error: 8.06
# Real: 82.00 Predicho: 63.72. Error: 18.28
# Real: 50.00 Predicho: 54.27. Error: -4.27
# Real: 80.00 Predicho: 61.40. Error: 18.60
# Real: 70.00 Predicho: 59.99. Error: 10.01
# Real: 38.00 Predicho: 34.95. Error: 3.05
# Real: 75.00 Predicho: 70.26. Error: 4.74
# Real: 50.00 Predicho: 60.97. Error: -10.97
# Real: 30.00 Predicho: 25.18. Error: 4.82
# Real: 69.00 Predicho: 37.10. Error: 31.90
# Real: 85.00 Predicho: 66.46. Error: 18.54
# Real: 95.00 Predicho: 116.62. Error: -21.62
# Real: 60.00 Predicho: 75.03. Error: -15.03
# Real: 35.00 Predicho: 26.27. Error: 8.73
# Real: 50.00 Predicho: 27.48. Error: 22.52
# Real: 50.00 Predicho: 108.67. Error: -58.67
# Real: 25.00 Predicho: 25.39. Error: -0.39
# Real: 49.00 Predicho: 57.95. Error: -8.95
# Real: 99.00 Predicho: 94.35. Error: 4.65
# Real: 81.00 Predicho: 66.88. Error: 14.12
# Real: 69.00 Predicho: 75.84. Error: -6.84
# Real: 87.00 Predicho: 90.27. Error: -3.27
# Real: 27.00 Predicho: 48.99. Error: -21.99
# Real: 110.00 Predicho: 60.50. Error: 49.50
# Real: 30.00 Predicho: 36.77. Error: -6.77
# Real: 90.00 Predicho: 75.19. Error: 14.81
# Real: 50.00 Predicho: 33.92. Error: 16.08
# Real: 65.00 Predicho: 71.18. Error: -6.18
# Real: 30.00 Predicho: 63.39. Error: -33.39
# Real: 33.00 Predicho: 36.27. Error: -3.27
# Real: 46.00 Predicho: 76.14. Error: -30.14
# Real: 20.00 Predicho: 22.55. Error: -2.55
# Real: 60.00 Predicho: 57.16. Error: 2.84
# Real: 90.00 Predicho: 102.60. Error: -12.60
# Real: 21.00 Predicho: 29.94. Error: -8.94
# Real: 20.00 Predicho: 26.26. Error: -6.26
# Real: 60.00 Predicho: 58.43. Error: 1.57
# Real: 20.00 Predicho: 18.64. Error: 1.36
# Real: 76.00 Predicho: 54.51. Error: 21.49
# Real: 35.00 Predicho: 29.82. Error: 5.18
# Real: 55.00 Predicho: 70.65. Error: -15.65
# Real: 17.00 Predicho: 34.50. Error: -17.50
# Real: 130.00 Predicho: 120.65. Error: 9.35
# Real: 30.00 Predicho: 30.95. Error: -0.95
# Real: 90.00 Predicho: 109.45. Error: -19.45
# Real: 42.00 Predicho: 39.08. Error: 2.92
# Real: 55.00 Predicho: 56.11. Error: -1.11
# Real: 75.00 Predicho: 47.12. Error: 27.88
# Real: 60.00 Predicho: 51.09. Error: 8.91
# Real: 85.00 Predicho: 77.98. Error: 7.02
# Real: 18.00 Predicho: 35.66. Error: -17.66
# Real: 122.00 Predicho: 44.81. Error: 77.19
# Real: 60.00 Predicho: 75.87. Error: -15.87
# Real: 16.00 Predicho: 21.01. Error: -5.01
# Real: 170.00 Predicho: 149.54. Error: 20.46
# Real: 150.00 Predicho: 75.37. Error: 74.63
# Real: 100.00 Predicho: 73.36. Error: 26.64
# Real: 25.00 Predicho: 26.42. Error: -1.42
# Real: 60.00 Predicho: 76.35. Error: -16.35
# Real: 19.00 Predicho: 28.50. Error: -9.50
# Real: 120.00 Predicho: 114.80. Error: 5.20
# Real: 25.00 Predicho: 22.60. Error: 2.40
# Real: 25.00 Predicho: 29.75. Error: -4.75
# Real: 55.00 Predicho: 58.55. Error: -3.55
# Real: 55.00 Predicho: 61.94. Error: -6.94
# Real: 55.00 Predicho: 48.87. Error: 6.13
# Real: 36.00 Predicho: 49.40. Error: -13.40
# Real: 65.00 Predicho: 79.40. Error: -14.40
# Real: 50.00 Predicho: 48.82. Error: 1.18
# Real: 41.00 Predicho: 29.86. Error: 11.14
# Real: 30.00 Predicho: 34.20. Error: -4.20
# Real: 20.00 Predicho: 18.91. Error: 1.09
# Real: 77.00 Predicho: 96.48. Error: -19.48
# Real: 70.00 Predicho: 56.68. Error: 13.32
# Real: 60.00 Predicho: 50.15. Error: 9.85
# Real: 75.00 Predicho: 76.30. Error: -1.30
# Real: 75.00 Predicho: 55.60. Error: 19.40
# Real: 50.00 Predicho: 36.74. Error: 13.26
# Real: 190.00 Predicho: 140.12. Error: 49.88
# Real: 55.00 Predicho: 88.59. Error: -33.59
# Real: 55.00 Predicho: 67.72. Error: -12.72
# Real: 30.00 Predicho: 32.26. Error: -2.26
# Real: 69.00 Predicho: 61.21. Error: 7.79
# Real: 35.00 Predicho: 81.68. Error: -46.68
# Real: 65.00 Predicho: 90.60. Error: -25.60
# Real: 70.00 Predicho: 54.99. Error: 15.01
# Real: 21.00 Predicho: 29.91. Error: -8.91
# Real: 124.00 Predicho: 76.33. Error: 47.67
# Real: 29.00 Predicho: 35.74. Error: -6.74
# Real: 53.00 Predicho: 80.91. Error: -27.91
# Real: 65.00 Predicho: 40.04. Error: 24.96
# Real: 70.00 Predicho: 82.65. Error: -12.65
# Real: 85.00 Predicho: 97.15. Error: -12.15
# Real: 37.00 Predicho: 24.73. Error: 12.27
# Real: 14.00 Predicho: 34.23. Error: -20.23
# Real: 45.00 Predicho: 57.42. Error: -12.42
# Real: 38.00 Predicho: 57.34. Error: -19.34
# Real: 95.00 Predicho: 83.48. Error: 11.52
# Real: 23.00 Predicho: 33.60. Error: -10.60
# Real: 42.00 Predicho: 38.27. Error: 3.73
# Real: 32.00 Predicho: 32.87. Error: -0.87
# Real: 30.00 Predicho: 31.64. Error: -1.64
# Real: 70.00 Predicho: 53.28. Error: 16.72
# Real: 50.00 Predicho: 49.47. Error: 0.53
# Real: 149.00 Predicho: 64.49. Error: 84.51
# Real: 29.00 Predicho: 42.19. Error: -13.19
# Real: 26.00 Predicho: 37.57. Error: -11.57
# Real: 50.00 Predicho: 31.83. Error: 18.17
# Real: 18.00 Predicho: 29.03. Error: -11.03
# Real: 56.00 Predicho: 97.94. Error: -41.94
# Real: 20.00 Predicho: 27.30. Error: -7.30
# Real: 29.00 Predicho: 27.56. Error: 1.44
# Real: 148.00 Predicho: 96.69. Error: 51.31
# Real: 50.00 Predicho: 65.35. Error: -15.35
# Real: 27.00 Predicho: 34.07. Error: -7.07
# Real: 15.00 Predicho: 23.86. Error: -8.86
# Real: 48.00 Predicho: 40.11. Error: 7.89
# Real: 90.00 Predicho: 73.70. Error: 16.30
# Real: 30.00 Predicho: 30.17. Error: -0.17
# Real: 30.00 Predicho: 30.06. Error: -0.06
# Real: 57.00 Predicho: 82.15. Error: -25.15
# Real: 56.00 Predicho: 70.62. Error: -14.62
# Real: 25.00 Predicho: 20.01. Error: 4.99
# Real: 100.00 Predicho: 34.79. Error: 65.21
# Real: 70.00 Predicho: 80.23. Error: -10.23
# Real: 32.00 Predicho: 28.59. Error: 3.41
# Real: 30.00 Predicho: 24.80. Error: 5.20
# Real: 110.00 Predicho: 106.89. Error: 3.11
# Real: 75.00 Predicho: 94.38. Error: -19.38
# Real: 43.00 Predicho: 38.97. Error: 4.03
# Real: 89.00 Predicho: 78.63. Error: 10.37
# Real: 60.00 Predicho: 61.08. Error: -1.08
# Real: 115.00 Predicho: 72.00. Error: 43.00
# Real: 42.00 Predicho: 52.93. Error: -10.93
# Real: 56.00 Predicho: 73.53. Error: -17.53
# Real: 14.00 Predicho: 20.07. Error: -6.07
# Real: 13.00 Predicho: 26.31. Error: -13.31
# Real: 59.00 Predicho: 64.46. Error: -5.46
# Real: 55.00 Predicho: 55.95. Error: -0.95
# Real: 43.00 Predicho: 33.46. Error: 9.54
# Real: 45.00 Predicho: 51.18. Error: -6.18
# Real: 33.00 Predicho: 33.27. Error: -0.27
# Real: 20.00 Predicho: 29.22. Error: -9.22
# Real: 85.00 Predicho: 101.73. Error: -16.73
# Real: 25.00 Predicho: 28.11. Error: -3.11
# Real: 130.00 Predicho: 109.55. Error: 20.45
# Real: 30.00 Predicho: 34.53. Error: -4.53
# Real: 170.00 Predicho: 113.25. Error: 56.75
# Real: 49.00 Predicho: 59.84. Error: -10.84
# Real: 92.00 Predicho: 102.47. Error: -10.47
# Real: 49.00 Predicho: 56.47. Error: -7.47
# Real: 45.00 Predicho: 68.90. Error: -23.90
# Real: 110.00 Predicho: 100.85. Error: 9.15
# Real: 43.00 Predicho: 32.76. Error: 10.24
# Real: 90.00 Predicho: 89.64. Error: 0.36
# Real: 60.00 Predicho: 88.58. Error: -28.58
# Real: 160.00 Predicho: 159.54. Error: 0.46
# Real: 29.00 Predicho: 33.55. Error: -4.55
# Real: 55.00 Predicho: 67.69. Error: -12.69
# Real: 40.00 Predicho: 28.45. Error: 11.55
# Real: 90.00 Predicho: 93.98. Error: -3.98
# Real: 50.00 Predicho: 82.84. Error: -32.84
# Real: 49.00 Predicho: 51.25. Error: -2.25
# Real: 75.00 Predicho: 69.16. Error: 5.84
# Real: 35.00 Predicho: 30.77. Error: 4.23
# Real: 60.00 Predicho: 85.50. Error: -25.50
# Real: 50.00 Predicho: 49.48. Error: 0.52
# Real: 60.00 Predicho: 53.31. Error: 6.69
# Real: 50.00 Predicho: 57.57. Error: -7.57
# Real: 28.00 Predicho: 37.46. Error: -9.46
# Real: 110.00 Predicho: 97.82. Error: 12.18
# Real: 50.00 Predicho: 75.61. Error: -25.61
# Real: 81.00 Predicho: 69.10. Error: 11.90
# Real: 35.00 Predicho: 36.40. Error: -1.40
# Real: 30.00 Predicho: 32.71. Error: -2.71
# Real: 63.00 Predicho: 76.77. Error: -13.77
# Real: 55.00 Predicho: 49.50. Error: 5.50
# Real: 64.00 Predicho: 79.37. Error: -15.37
# Real: 20.00 Predicho: 37.66. Error: -17.66
# Real: 19.00 Predicho: 22.23. Error: -3.23
# Real: 69.00 Predicho: 66.38. Error: 2.62
# Real: 30.00 Predicho: 32.53. Error: -2.53
# Real: 17.00 Predicho: 27.30. Error: -10.30
# Real: 19.00 Predicho: 24.86. Error: -5.86
# Real: 60.00 Predicho: 82.63. Error: -22.63
# Real: 89.00 Predicho: 112.57. Error: -23.57
# Real: 75.00 Predicho: 85.55. Error: -10.55
# Real: 43.00 Predicho: 69.89. Error: -26.89
# Real: 40.00 Predicho: 41.31. Error: -1.31
# Real: 20.00 Predicho: 32.76. Error: -12.76
# Real: 80.00 Predicho: 55.75. Error: 24.25
# Real: 80.00 Predicho: 72.80. Error: 7.20
# Real: 60.00 Predicho: 64.66. Error: -4.66
# Real: 75.00 Predicho: 68.48. Error: 6.52
# Real: 23.00 Predicho: 27.51. Error: -4.51
# Real: 30.00 Predicho: 35.53. Error: -5.53
# Real: 45.00 Predicho: 70.99. Error: -25.99
# Real: 20.00 Predicho: 26.97. Error: -6.97
# Real: 21.00 Predicho: 31.42. Error: -10.42
# Real: 55.00 Predicho: 90.79. Error: -35.79

# %% [markdown]
# Despues haber utilizado diferentes modelos y observar sus resultados vemos que el random forest da el mejor resultado con un error medio de prediccion de 21euro.
